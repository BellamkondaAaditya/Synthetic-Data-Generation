# %% [markdown]
# ## Attempt 1: composit score function

# %%
from pathlib import Path
from typing import Tuple
import pandas as pd
import numpy as np
import torch
from tqdm.auto import tqdm                 # NEW
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import Metadata
from sdv.evaluation.single_table import evaluate_quality
from sdmetrics.reports.single_table import QualityReport
from sdmetrics.single_table import LogisticDetection, RangeCoverage


from sdmetrics.reports.single_table import QualityReport
from sdmetrics.single_table import LogisticDetection, RangeCoverage

def score(real_df, synth_df, metadata_obj) -> float:
    """Return composite quality/utility score (↑ better)."""
    meta_full = metadata_obj.to_dict()
    meta_single = meta_full["tables"]["table"]          # <─ unwrap here

    report = QualityReport()
    report.generate(real_df, synth_df, meta_single, verbose=False)
    base = report.get_score()

    auc = LogisticDetection.compute(real_df, synth_df, metadata=meta_single)
    cov = RangeCoverage.compute(real_df, synth_df, metadata=meta_single)

    return base - 0.5 * auc + 0.2 * cov

def train_until_convergence(
    df_slice: pd.DataFrame,
    *,
    service_code: str,
    max_epochs: int = 2_000,
    step: int = 50,
    patience: int = 4,
    outdir: Path = Path("checkpoints/models")
) -> Tuple[CTGANSynthesizer, int, float]:
    """
    CTGAN fit with early-stopping based on SDV quality metrics.
    Shows a live progress bar (tqdm) for the outer training loop.
    """
    outdir.mkdir(parents=True, exist_ok=True)

    metadata = Metadata.detect_from_dataframes(data={"table": df_slice})

    best_s, best_ep, bad = -np.inf, 0, 0
    cur = 0

    # ─── progress bar ────────────────────────────────────────────────────────────
    bar = tqdm(
        total=max_epochs,
        desc=f"CTGAN [{service_code}]",
        unit="epoch",
        leave=True,
        dynamic_ncols=True,
    )
    # ─────────────────────────────────────────────────────────────────────────────

    while cur < max_epochs and bad < patience:
        synth = CTGANSynthesizer(metadata=metadata, epochs=step, verbose=False)
        synth.fit(df_slice)
        cur += step
        bar.update(step)                   # update progress bar

        synthetic_sample = synth.sample(num_rows=len(df_slice))
        s = score(df_slice, synthetic_sample, metadata)

        if s > best_s + 1e-3:
            model_path = outdir / f"{service_code}_ep{cur}.pkl"
            synth.save(str(model_path))
            best_s, best_ep, bad = s, cur, 0
        else:
            bad += 1

    bar.close()                            # tidy up the bar

    best_model_path = outdir / f"{service_code}_ep{best_ep}.pkl"
    best_synth = CTGANSynthesizer.load(str(best_model_path))
    return best_synth, best_ep, best_s

# %%
import pandas as pd

# Load your filtered dataset from pickle
DATA_PATH = "filtered_data/df_v2_filtered.pkl"
TOP_K     = 5   # Train this many CTGANs

df = pd.read_pickle(DATA_PATH)

# Select top-K most frequent SERVICE_CODEs
codes = df["service_code_description"].value_counts().head(TOP_K).index.tolist()
codes
# Out:
# ['ASSIST MEMBER OF THE PUBLIC',
#  'CONCERN FOR PERSON',
#  'DISTURBANCE',
#  'THEFT',
#  'DOMESTIC INCIDENT']

# %%
results = []

for code in codes:
    print(f"\n🟢  [{code}] starting …")
    slice_df = df[df["service_code_description"] == code].copy()
    
    best_model, best_epoch, best_score = train_until_convergence(
        slice_df,
        service_code=code,
        outdir=Path("checkpoints/models")
    )

    results.append({"code": code, "epoch": best_epoch, "score": best_score})
    print(f"✅  [{code}] finished at epoch {best_epoch}  (score={best_score:.4f})")
# Out:
# 🟢  [ASSIST MEMBER OF THE PUBLIC] starting …
# CTGAN [ASSIST MEMBER OF THE PUBLIC]:   0%|          | 0/2000 [00:00<?, ?epoch/s]
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ✅  [ASSIST MEMBER OF THE PUBLIC] finished at epoch 50  (score=0.7195)
#
# 🟢  [CONCERN FOR PERSON] starting …
# CTGAN [CONCERN FOR PERSON]:   0%|          | 0/2000 [00:00<?, ?epoch/s]
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ✅  [CONCERN FOR PERSON] finished at epoch 150  (score=0.7219)
#
# 🟢  [DISTURBANCE] starting …
# CTGAN [DISTURBANCE]:   0%|          | 0/2000 [00:00<?, ?epoch/s]
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ✅  [DISTURBANCE] finished at epoch 250  (score=0.7753)
#
# 🟢  [THEFT] starting …
# CTGAN [THEFT]:   0%|          | 0/2000 [00:00<?, ?epoch/s]
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ✅  [THEFT] finished at epoch 50  (score=0.7562)
#
# 🟢  [DOMESTIC INCIDENT] starting …
# CTGAN [DOMESTIC INCIDENT]:   0%|          | 0/2000 [00:00<?, ?epoch/s]
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ✅  [DOMESTIC INCIDENT] finished at epoch 150  (score=0.7549)

# %%
ledger = pd.DataFrame(results)

# %%
ledger
# Out:
#                           code  epoch     score
# 0  ASSIST MEMBER OF THE PUBLIC     50  0.719502
# 1           CONCERN FOR PERSON    150  0.721933
# 2                  DISTURBANCE    250  0.775320
# 3                        THEFT     50  0.756218
# 4            DOMESTIC INCIDENT    150  0.754918

# %% [markdown]
# ## Attempt 2: Checking convergence measurement on THEFT

# %%
from pathlib import Path
import numpy as np, pandas as pd
from tqdm.auto import tqdm

from sdv.single_table import CTGANSynthesizer
from sdv.metadata import Metadata
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ╔══════════ 2 · LOSS-BASED CONVERGENCE ══╗
def losses_converged(
    g_hist: list[float],
    d_hist: list[float],
    *,
    window: int  = 10,      # look at the last 10 logged points
    epsilon: float = 0.1,  # G & D must be this close *on average*
    drift: float   = 0.25,  # reject if either series moves >±0.10
) -> bool:
    """
    True when, over the last `window` points:
      – mean(|G − D|) ≤ ε
      – max drift within each series ≤ `drift`
    """
    if len(g_hist) < window + 1:
        return False

    g_win, d_win = np.array(g_hist[-window:]), np.array(d_hist[-window:])
    balanced = np.abs(g_win - d_win).mean() <= epsilon
    stable   = (g_win.ptp() <= drift) and (d_win.ptp() <= drift)
    return balanced and stable


# ╔══════════ 3 · TRAIN UNTIL CONVERGENCE ══╗
def train_until_convergence(
    df_slice: pd.DataFrame,
    *,
    service_code: str,
    max_epochs: int = 2_000,
    step: int = 50,
    outdir: Path = Path("checkpoints/models"),
):
    outdir.mkdir(parents=True, exist_ok=True)
    metadata = Metadata.detect_from_dataframes({"table": df_slice})

    g_hist, d_hist, cur = [], [], 0
    bar = tqdm(total=max_epochs, desc=f"CTGAN [{service_code}]",
               unit="epoch", dynamic_ncols=True)

    while cur < max_epochs:
        synth = CTGANSynthesizer(metadata=metadata, epochs=step, verbose=False, cuda=True)
        synth.fit(df_slice)

        cur += step
        bar.update(step)

        # — official helper (SDV ≥1.6, incl. 1.23.0) —
        losses = synth.get_loss_values()          # 
        g_hist.extend(losses["Generator Loss"].tolist())
        d_hist.extend(losses["Discriminator Loss"].tolist())

        if losses_converged(g_hist, d_hist):
            bar.set_postfix_str("loss-converged")
            break

    bar.close()
    model_path = outdir / f"{service_code}_final.pkl"
    synth.save(model_path)
    return synth, cur, model_path

# ╔══════════ 4 · RUN FOR “THEFT” ONLY ═════╗
DATA_PATH   = "filtered_data/df_v2_filtered.pkl"
TARGET_CODE = "THEFT"

df = pd.read_pickle(DATA_PATH)
if TARGET_CODE not in df["service_code_description"].unique():
    raise ValueError(f'"{TARGET_CODE}" not found in column.')

slice_df = df[df["service_code_description"] == TARGET_CODE].copy()
print(f"\n👟  Training CTGAN for service code: {TARGET_CODE} "
      f"(n={len(slice_df):,} rows)")

model, final_epoch, path = train_until_convergence(
    slice_df, service_code=TARGET_CODE
)

print(f"\n✅  Converged after {final_epoch} epochs — model saved to {path}")
# Out:
# 👟  Training CTGAN for service code: THEFT (n=87,517 rows)
# CTGAN [THEFT]:   0%|          | 0/2000 [00:00<?, ?epoch/s]
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 83
#      79 slice_df = df[df["service_code_description"] == TARGET_CODE].copy()
#      80 print(f"\n👟  Training CTGAN for service code: {TARGET_CODE} "
#      81       f"(n={len(slice_df):,} rows)")
# ---> 83 model, final_epoch, path = train_until_convergence(
#      84     slice_df, service_code=TARGET_CODE
#      85 )
#      87 print(f"\n✅  Converged after {final_epoch} epochs — model saved to {path}")
#      88 try:
#
# Cell In[1], line 52, in train_until_convergence(df_slice, service_code, max_epochs, step, outdir)
#      50 while cur < max_epochs:
#      51     synth = CTGANSynthesizer(metadata=metadata, epochs=step, verbose=False, cuda=True)
# ---> 52     synth.fit(df_slice)
#      54     cur += step
#      55     bar.update(step)
#
# File /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:666, in BaseSynthesizer.fit(self, data)
#     664 is_converted = self._store_and_convert_original_cols(data)
#     665 processed_data = self.preprocess(data)
# --> 666 self.fit_processed_data(processed_data)
#     667 if is_converted:
#     668     data.columns = self._original_columns
#
# File /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:635, in BaseSynthesizer.fit_processed_data(self, processed_data)
#     633 check_synthesizer_version(self, is_fit_method=True, compare_operator=operator.lt)
#     634 if not processed_data.empty:
# --> 635     self._fit(processed_data)
#     637 self._fitted = True
#     638 self._fitted_date = datetime.datetime.today().strftime('%Y-%m-%d')
#
# File /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:303, in CTGANSynthesizer._fit(self, processed_data)
#     301 with warnings.catch_warnings():
#     302     warnings.filterwarnings('ignore', message='.*Attempting to run cuBLAS.*')
# --> 303     self._model.fit(processed_data, discrete_columns=discrete_columns)
#
# File /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/ctgan/synthesizers/base.py:50, in random_state.<locals>.wrapper(self, *args, **kwargs)
#      48 def wrapper(self, *args, **kwargs):
#      49     if self.random_states is None:
# ---> 50         return function(self, *args, **kwargs)
#      52     else:
#      53         with set_random_states(self.random_states, self.set_random_state):
#
# File /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/ctgan/synthesizers/ctgan.py:465, in CTGAN.fit(self, train_data, discrete_columns, epochs)
#     462     loss_g = -torch.mean(y_fake) + cross_entropy
#     464     optimizerG.zero_grad(set_to_none=False)
# --> 465     loss_g.backward()
#     466     optimizerG.step()
#     468 generator_loss = loss_g.detach().cpu().item()
#
# File /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/torch/_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)    646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/torch/autograd/__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
#     351 # some Python versions print out the first line of a multi-line function
#     352 # calls in the traceback and some print out the last line
# --> 353 _engine_run_backward(
#     354     tensors,
#     355     grad_tensors_,
#     356     retain_graph,
#     357     create_graph,
#     358     inputs,
#     359     allow_unreachable=True,
#     360     accumulate_grad=True,
#     361 )
#
# File /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/torch/autograd/graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# Visualising the loss functions
fig = model.get_loss_values_plot()
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Visualising the loss functions
# ----> 2 fig = model.get_loss_values_plot()
#       3 fig.show()
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Attempt 3: Moving average approach at detecting convergence for CTGANS

# %%
from pathlib import Path
from typing import Tuple
import pandas as pd
import numpy as np
import torch
from tqdm.auto import tqdm

from sdv.single_table import CTGANSynthesizer
from sdv.metadata import Metadata

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# ─────────────── 1 · EMA-Based Convergence Detector ───────────────
def find_convergence_epoch(
    loss_df: pd.DataFrame,
    *,
    smooth_span: int = 25,
    window: int = 10,
    epsilon: float = 0.05,
    drift: float = 0.10,
) -> int | None:
    """Detect first epoch where G/D smoothed losses are both close and stable."""
    g_s = loss_df["Generator Loss"].ewm(span=smooth_span, adjust=False).mean().to_numpy()
    d_s = loss_df["Discriminator Loss"].ewm(span=smooth_span, adjust=False).mean().to_numpy()
    epochs = loss_df["Epoch"].to_numpy()

    for i in range(window, len(loss_df)):
        g_win, d_win = g_s[i - window:i], d_s[i - window:i]
        gap_ok = np.abs(g_win - d_win).mean() <= epsilon
        drift_ok = (g_win.ptp() <= drift) and (d_win.ptp() <= drift)

        if gap_ok and drift_ok:
            return int(epochs[i])
    return None


# ─────────────── 2 · Training Function ───────────────
def train_until_convergence(
    df_slice: pd.DataFrame,
    *,
    service_code: str,
    max_epochs: int = 2000,
    step: int = 50,
    outdir: Path = Path("checkpoints_3/models")
) -> Tuple[CTGANSynthesizer, int, Path]:
    """Train CTGAN with early stopping based on smoothed loss convergence."""
    outdir.mkdir(parents=True, exist_ok=True)
    metadata = Metadata.detect_from_dataframes({"table": df_slice})

    full_loss_df = pd.DataFrame(columns=["Epoch", "Generator Loss", "Discriminator Loss"])
    cur_epoch = 0
    bar = tqdm(total=max_epochs, desc=f"CTGAN [{service_code}]", unit="epoch", dynamic_ncols=True)

    while cur_epoch < max_epochs:
        synth = ctgan = CTGANSynthesizer(
            metadata,
            epochs=800,
            batch_size=1024,
            pac=8,
            embedding_dim=128,
            generator_dim=(256, 256),
            discriminator_dim=(256, 256),
            generator_lr=2e-4,
            discriminator_lr=2e-4,
            cuda=True,
            verbose=True
        )
        synth.fit(df_slice)
        bar.update(step)
        cur_epoch += step

        # Extract step loss history and adjust epoch numbers
        step_losses = synth.get_loss_values().copy()
        step_losses["Epoch"] += (cur_epoch - step)
        full_loss_df = pd.concat([full_loss_df, step_losses], ignore_index=True)

        # Check convergence after enough points
        if len(full_loss_df) >= 35:  # 25 for EMA + 10 for window
            conv_epoch = find_convergence_epoch(full_loss_df)
            if conv_epoch is not None and conv_epoch <= cur_epoch:
                bar.set_postfix_str(f"converged @ {conv_epoch}")
                break

    bar.close()

    model_path = outdir / f"{service_code}_final.pkl"
    synth.save(str(model_path))
    return synth, cur_epoch, model_path


# ─────────────── 3 · Run for Top-5 Codes ───────────────
DATA_PATH = "filtered_data/df_v2_filtered.pkl"
TOP_K = 5

df = pd.read_pickle(DATA_PATH)
codes = df["service_code_description"].value_counts().head(TOP_K).index.tolist()

print(f"\nTop-{TOP_K} service codes: {codes}\n")

for code in codes:
    slice_df = df[df["service_code_description"] == code].copy()
    print(f"\nTraining CTGAN for '{code}' ({len(slice_df):,} rows)")

    model, final_epoch, path = train_until_convergence(
        slice_df,
        service_code=code,
        max_epochs=2000,
        step=50,
        outdir=Path("checkpoints_3/models")
    )

    print(f"'{code}' converged after {final_epoch} epochs — model saved to {path}")
# Out:
# Top-5 service codes: ['ASSIST MEMBER OF THE PUBLIC', 'CONCERN FOR PERSON', 'DISTURBANCE', 'THEFT', 'DOMESTIC INCIDENT']
#
#
# Training CTGAN for 'ASSIST MEMBER OF THE PUBLIC' (169,406 rows)
# CTGAN [ASSIST MEMBER OF THE PUBLIC]:   0%|          | 0/2000 [00:00<?, ?epoch/s]
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
#
#
#
#   0%|          | 0/800 [00:00<?, ?it/s]
#
#
# Gen. (0.00) | Discrim. (0.00):   0%|          | 0/800 [00:00<?, ?it/s]
#
#
# Gen. (1.02) | Discrim. (0.05):   0%|          | 0/800 [00:04<?, ?it/s]
#
#
# Gen. (1.02) | Discrim. (0.05):   0%|          | 1/800 [00:04<1:00:15,  4.53s/it]
#
#
# Gen. (0.94) | Discrim. (-0.02):   0%|          | 1/800 [00:09<1:00:15,  4.53s/it]
#
#
# Gen. (0.94) | Discrim. (-0.02):   0%|          | 2/800 [00:09<1:00:10,  4.52s/it]
#
#
# Gen. (0.42) | Discrim. (-0.01):   0%|          | 2/800 [00:13<1:00:10,  4.52s/it]
#
#
# Gen. (0.42) | Discrim. (-0.01):   0%|          | 3/800 [00:13<1:00:08,  4.53s/it]
#
#
# Gen. (-0.40) | Discrim. (-0.03):   0%|          | 3/800 [00:18<1:00:08,  4.53s/it]
#
#
# Gen. (-0.40) | Discrim. (-0.03):   0%|          | 4/800 [00:18<59:54,  4.52s/it]
#
#
# Gen. (-0.54) | Discrim. (0.01):   0%|          | 4/800 [00:22<59:54,  4.52s/it]
#
#
# Gen. (-0.54) | Discrim. (0.01):   1%|          | 5/800 [00:22<59:40,  4.50s/it]
#
#
# Gen. (-0.83) | Discrim. (0.02):   1%|          | 5/800 [00:27<59:40,  4.50s/it]
#
#
# Gen. (-0.83) | Discrim. (0.02):   1%|          | 6/800 [00:27<59:41,  4.51s/it]
#
#
# Gen. (-0.77) | Discrim. (0.03):   1%|          | 6/800 [00:31<59:41,  4.51s/it]
#
#
# Gen. (-0.77) | Discrim. (0.03):   1%|          | 7/800 [00:31<59:31,  4.50s/it]
#
#
# Gen. (-0.85) | Discrim. (0.02):   1%|          | 7/800 [00:36<59:31,  4.50s/it]
#
#
# Gen. (-0.85) | Discrim. (0.02):   1%|          | 8/800 [00:36<59:19,  4.49s/it]
#
#
# Gen. (-0.70) | Discrim. (0.01):   1%|          | 8/800 [00:40<59:19,  4.49s/it]
#
#
# Gen. (-0.70) | Discrim. (0.01):   1%|          | 9/800 [00:40<59:13,  4.49s/it]
#
#
# Gen. (-0.85) | Discrim. (0.03):   1%|          | 9/800 [00:44<59:13,  4.49s/it]
#
#
# Gen. (-0.85) | Discrim. (0.03):   1%|▏         | 10/800 [00:44<58:58,  4.48s/it]
#
#
# Gen. (-0.87) | Discrim. (0.03):   1%|▏         | 10/800 [00:49<58:58,  4.48s/it]
#
#
# Gen. (-0.87) | Discrim. (0.03):   1%|▏         | 11/800 [00:49<58:48,  4.47s/it]
#
#
# Gen. (-0.91) | Discrim. (0.02):   1%|▏         | 11/800 [00:53<58:48,  4.47s/it]
#
#
# Gen. (-0.91) | Discrim. (0.02):   2%|▏         | 12/800 [00:53<58:38,  4.47s/it]
#
#
# Gen. (-0.94) | Discrim. (0.00):   2%|▏         | 12/800 [00:58<58:38,  4.47s/it]
#
#
# Gen. (-0.94) | Discrim. (0.00):   2%|▏         | 13/800 [00:58<58:28,  4.46s/it]
#
#
# Gen. (-0.93) | Discrim. (-0.02):   2%|▏         | 13/800 [01:02<58:28,  4.46s/it]
#
#
# Gen. (-0.93) | Discrim. (-0.02):   2%|▏         | 14/800 [01:02<58:19,  4.45s/it]
#
#
# Gen. (-1.00) | Discrim. (-0.01):   2%|▏         | 14/800 [01:07<58:19,  4.45s/it]
#
#
# Gen. (-1.00) | Discrim. (-0.01):   2%|▏         | 15/800 [01:07<58:13,  4.45s/it]
#
#
# Gen. (-1.01) | Discrim. (0.04):   2%|▏         | 15/800 [01:11<58:13,  4.45s/it]
#
#
# Gen. (-1.01) | Discrim. (0.04):   2%|▏         | 16/800 [01:11<58:07,  4.45s/it]
#
#
# Gen. (-0.98) | Discrim. (0.04):   2%|▏         | 16/800 [01:16<58:07,  4.45s/it]
#
#
# Gen. (-0.98) | Discrim. (0.04):   2%|▏         | 17/800 [01:16<58:01,  4.45s/it]
#
#
# Gen. (-1.01) | Discrim. (0.02):   2%|▏         | 17/800 [01:20<58:01,  4.45s/it]
#
#
# Gen. (-1.01) | Discrim. (0.02):   2%|▏         | 18/800 [01:20<57:56,  4.45s/it]
#
#
# Gen. (-1.10) | Discrim. (0.01):   2%|▏         | 18/800 [01:24<57:56,  4.45s/it]
#
#
# Gen. (-1.10) | Discrim. (0.01):   2%|▏         | 19/800 [01:24<57:50,  4.44s/it]
#
#
# Gen. (-1.07) | Discrim. (-0.01):   2%|▏         | 19/800 [01:29<57:50,  4.44s/it]
#
#
# Gen. (-1.07) | Discrim. (-0.01):   2%|▎         | 20/800 [01:29<57:52,  4.45s/it]
#
#
# Gen. (-1.19) | Discrim. (0.01):   2%|▎         | 20/800 [01:33<57:52,  4.45s/it]
#
#
# Gen. (-1.19) | Discrim. (0.01):   3%|▎         | 21/800 [01:33<57:53,  4.46s/it]
#
#
# Gen. (-1.12) | Discrim. (-0.05):   3%|▎         | 21/800 [01:38<57:53,  4.46s/it]
#
#
# Gen. (-1.12) | Discrim. (-0.05):   3%|▎         | 22/800 [01:38<57:44,  4.45s/it]
#
#
# Gen. (-1.11) | Discrim. (-0.05):   3%|▎         | 22/800 [01:42<57:44,  4.45s/it]
#
#
# Gen. (-1.11) | Discrim. (-0.05):   3%|▎         | 23/800 [01:42<57:37,  4.45s/it]
#
#
# Gen. (-1.13) | Discrim. (0.05):   3%|▎         | 23/800 [01:47<57:37,  4.45s/it]
#
#
# Gen. (-1.13) | Discrim. (0.05):   3%|▎         | 24/800 [01:47<57:31,  4.45s/it]
#
#
# Gen. (-1.20) | Discrim. (-0.02):   3%|▎         | 24/800 [01:51<57:31,  4.45s/it]
#
#
# Gen. (-1.20) | Discrim. (-0.02):   3%|▎         | 25/800 [01:51<57:27,  4.45s/it]
#
#
# Gen. (-1.23) | Discrim. (0.04):   3%|▎         | 25/800 [01:56<57:27,  4.45s/it]
#
#
# Gen. (-1.23) | Discrim. (0.04):   3%|▎         | 26/800 [01:56<57:22,  4.45s/it]
#
#
# Gen. (-1.21) | Discrim. (-0.08):   3%|▎         | 26/800 [02:00<57:22,  4.45s/it]
#
#
# Gen. (-1.21) | Discrim. (-0.08):   3%|▎         | 27/800 [02:00<57:19,  4.45s/it]
#
#
# Gen. (-1.13) | Discrim. (0.01):   3%|▎         | 27/800 [02:05<57:19,  4.45s/it]
#
#
# Gen. (-1.13) | Discrim. (0.01):   4%|▎         | 28/800 [02:05<57:33,  4.47s/it]
#
#
# Gen. (-1.20) | Discrim. (0.03):   4%|▎         | 28/800 [02:09<57:33,  4.47s/it]
#
#
# Gen. (-1.20) | Discrim. (0.03):   4%|▎         | 29/800 [02:09<57:36,  4.48s/it]
#
#
# Gen. (-1.20) | Discrim. (0.02):   4%|▎         | 29/800 [02:14<57:36,  4.48s/it]
#
#
# Gen. (-1.20) | Discrim. (0.02):   4%|▍         | 30/800 [02:14<57:23,  4.47s/it]
#
#
# Gen. (-1.22) | Discrim. (-0.05):   4%|▍         | 30/800 [02:18<57:23,  4.47s/it]
#
#
# Gen. (-1.22) | Discrim. (-0.05):   4%|▍         | 31/800 [02:18<57:12,  4.46s/it]
#
#
# Gen. (-1.26) | Discrim. (0.02):   4%|▍         | 31/800 [02:22<57:12,  4.46s/it]
#
#
# Gen. (-1.26) | Discrim. (0.02):   4%|▍         | 32/800 [02:22<57:03,  4.46s/it]
#
#
# Gen. (-1.22) | Discrim. (-0.02):   4%|▍         | 32/800 [02:27<57:03,  4.46s/it]
#
#
# Gen. (-1.22) | Discrim. (-0.02):   4%|▍         | 33/800 [02:27<56:55,  4.45s/it]
#
#
# Gen. (-1.31) | Discrim. (0.02):   4%|▍         | 33/800 [02:31<56:55,  4.45s/it]
#
#
# Gen. (-1.31) | Discrim. (0.02):   4%|▍         | 34/800 [02:31<56:51,  4.45s/it]
#
#
# Gen. (-1.22) | Discrim. (-0.02):   4%|▍         | 34/800 [02:36<56:51,  4.45s/it]
#
#
# Gen. (-1.22) | Discrim. (-0.02):   4%|▍         | 35/800 [02:36<56:45,  4.45s/it]
#
#
# Gen. (-1.10) | Discrim. (-0.01):   4%|▍         | 35/800 [02:40<56:45,  4.45s/it]
#
#
# Gen. (-1.10) | Discrim. (-0.01):   4%|▍         | 36/800 [02:40<56:39,  4.45s/it]
#
#
# Gen. (-1.15) | Discrim. (0.01):   4%|▍         | 36/800 [02:45<56:39,  4.45s/it]
#
#
# Gen. (-1.15) | Discrim. (0.01):   5%|▍         | 37/800 [02:45<56:31,  4.45s/it]
#
#
# Gen. (-1.09) | Discrim. (-0.01):   5%|▍         | 37/800 [02:49<56:31,  4.45s/it]
#
#
# Gen. (-1.09) | Discrim. (-0.01):   5%|▍         | 38/800 [02:49<56:26,  4.44s/it]
#
#
# Gen. (-1.19) | Discrim. (-0.03):   5%|▍         | 38/800 [02:54<56:26,  4.44s/it]
#
#
# Gen. (-1.19) | Discrim. (-0.03):   5%|▍         | 39/800 [02:54<56:21,  4.44s/it]
#
#
# Gen. (-1.18) | Discrim. (0.05):   5%|▍         | 39/800 [02:58<56:21,  4.44s/it]
#
#
# Gen. (-1.18) | Discrim. (0.05):   5%|▌         | 40/800 [02:58<56:18,  4.45s/it]
#
#
# Gen. (-1.13) | Discrim. (-0.00):   5%|▌         | 40/800 [03:02<56:18,  4.45s/it]
#
#
# Gen. (-1.13) | Discrim. (-0.00):   5%|▌         | 41/800 [03:02<56:14,  4.45s/it]
#
#
# Gen. (-1.13) | Discrim. (0.01):   5%|▌         | 41/800 [03:07<56:14,  4.45s/it]
#
#
# Gen. (-1.13) | Discrim. (0.01):   5%|▌         | 42/800 [03:07<56:11,  4.45s/it]
#
#
# Gen. (-1.12) | Discrim. (-0.02):   5%|▌         | 42/800 [03:11<56:11,  4.45s/it]
#
#
# Gen. (-1.12) | Discrim. (-0.02):   5%|▌         | 43/800 [03:11<56:11,  4.45s/it]
#
#
# Gen. (-1.16) | Discrim. (-0.06):   5%|▌         | 43/800 [03:16<56:11,  4.45s/it]
#
#
# Gen. (-1.16) | Discrim. (-0.06):   6%|▌         | 44/800 [03:16<56:07,  4.45s/it]
#
#
# Gen. (-1.15) | Discrim. (0.01):   6%|▌         | 44/800 [03:20<56:07,  4.45s/it]
#
#
# Gen. (-1.15) | Discrim. (0.01):   6%|▌         | 45/800 [03:20<56:05,  4.46s/it]
#
#
# Gen. (-1.14) | Discrim. (-0.00):   6%|▌         | 45/800 [03:25<56:05,  4.46s/it]
#
#
# Gen. (-1.14) | Discrim. (-0.00):   6%|▌         | 46/800 [03:25<55:57,  4.45s/it]
#
#
# Gen. (-1.17) | Discrim. (0.01):   6%|▌         | 46/800 [03:29<55:57,  4.45s/it]
#
#
# Gen. (-1.17) | Discrim. (0.01):   6%|▌         | 47/800 [03:29<55:53,  4.45s/it]
#
#
# Gen. (-1.21) | Discrim. (0.02):   6%|▌         | 47/800 [03:34<55:53,  4.45s/it]
#
#
# Gen. (-1.21) | Discrim. (0.02):   6%|▌         | 48/800 [03:34<55:47,  4.45s/it]
#
#
# Gen. (-1.18) | Discrim. (0.05):   6%|▌         | 48/800 [03:38<55:47,  4.45s/it]
#
#
# Gen. (-1.18) | Discrim. (0.05):   6%|▌         | 49/800 [03:38<55:42,  4.45s/it]
#
#
# Gen. (-1.17) | Discrim. (0.05):   6%|▌         | 49/800 [03:43<55:42,  4.45s/it]
#
#
# Gen. (-1.17) | Discrim. (0.05):   6%|▋         | 50/800 [03:43<55:37,  4.45s/it]
#
#
# Gen. (-1.17) | Discrim. (0.03):   6%|▋         | 50/800 [03:47<55:37,  4.45s/it]
#
#
# Gen. (-1.17) | Discrim. (0.03):   6%|▋         | 51/800 [03:47<55:30,  4.45s/it]
#
#
# Gen. (-1.13) | Discrim. (-0.07):   6%|▋         | 51/800 [03:51<55:30,  4.45s/it]
#
#
# Gen. (-1.13) | Discrim. (-0.07):   6%|▋         | 52/800 [03:51<55:25,  4.45s/it]
#
#
# Gen. (-1.17) | Discrim. (0.04):   6%|▋         | 52/800 [03:56<55:25,  4.45s/it]
#
#
# Gen. (-1.17) | Discrim. (0.04):   7%|▋         | 53/800 [03:56<55:19,  4.44s/it]
#
#
# Gen. (-1.10) | Discrim. (-0.01):   7%|▋         | 53/800 [04:00<55:19,  4.44s/it]
#
#
# Gen. (-1.10) | Discrim. (-0.01):   7%|▋         | 54/800 [04:00<55:16,  4.45s/it]
#
#
# Gen. (-1.15) | Discrim. (-0.10):   7%|▋         | 54/800 [04:05<55:16,  4.45s/it]
#
#
# Gen. (-1.15) | Discrim. (-0.10):   7%|▋         | 55/800 [04:05<55:09,  4.44s/it]
#
#
# Gen. (-1.15) | Discrim. (0.01):   7%|▋         | 55/800 [04:09<55:09,  4.44s/it]
#
#
# Gen. (-1.15) | Discrim. (0.01):   7%|▋         | 56/800 [04:09<55:05,  4.44s/it]
#
#
# Gen. (-1.17) | Discrim. (-0.02):   7%|▋         | 56/800 [04:14<55:05,  4.44s/it]
#
#
# Gen. (-1.17) | Discrim. (-0.02):   7%|▋         | 57/800 [04:14<55:00,  4.44s/it]
#
#
# Gen. (-1.20) | Discrim. (-0.02):   7%|▋         | 57/800 [04:18<55:00,  4.44s/it]
#
#
# Gen. (-1.20) | Discrim. (-0.02):   7%|▋         | 58/800 [04:18<54:54,  4.44s/it]
#
#
# Gen. (-1.13) | Discrim. (-0.02):   7%|▋         | 58/800 [04:23<54:54,  4.44s/it]
#
#
# Gen. (-1.13) | Discrim. (-0.02):   7%|▋         | 59/800 [04:23<54:51,  4.44s/it]
#
#
# Gen. (-1.19) | Discrim. (-0.01):   7%|▋         | 59/800 [04:27<54:51,  4.44s/it]
#
#
# Gen. (-1.19) | Discrim. (-0.01):   8%|▊         | 60/800 [04:27<54:47,  4.44s/it]
#
#
# Gen. (-1.15) | Discrim. (-0.02):   8%|▊         | 60/800 [04:31<54:47,  4.44s/it]
#
#
# Gen. (-1.15) | Discrim. (-0.02):   8%|▊         | 61/800 [04:31<54:43,  4.44s/it]
#
#
# Gen. (-1.17) | Discrim. (0.01):   8%|▊         | 61/800 [04:36<54:43,  4.44s/it]
#
#
# Gen. (-1.17) | Discrim. (0.01):   8%|▊         | 62/800 [04:36<54:36,  4.44s/it]
#
#
# Gen. (-1.12) | Discrim. (-0.00):   8%|▊         | 62/800 [04:40<54:36,  4.44s/it]
#
#
# Gen. (-1.12) | Discrim. (-0.00):   8%|▊         | 63/800 [04:40<54:33,  4.44s/it]
#
#
# Gen. (-1.09) | Discrim. (0.02):   8%|▊         | 63/800 [04:45<54:33,  4.44s/it]
#
#
# Gen. (-1.09) | Discrim. (0.02):   8%|▊         | 64/800 [04:45<54:28,  4.44s/it]
#
#
# Gen. (-1.04) | Discrim. (0.00):   8%|▊         | 64/800 [04:49<54:28,  4.44s/it]
#
#
# Gen. (-1.04) | Discrim. (0.00):   8%|▊         | 65/800 [04:49<54:24,  4.44s/it]
#
#
# Gen. (-1.11) | Discrim. (0.04):   8%|▊         | 65/800 [04:54<54:24,  4.44s/it]
#
#
# Gen. (-1.11) | Discrim. (0.04):   8%|▊         | 66/800 [04:54<54:22,  4.44s/it]
#
#
# Gen. (-1.07) | Discrim. (-0.01):   8%|▊         | 66/800 [04:58<54:22,  4.44s/it]
#
#
# Gen. (-1.07) | Discrim. (-0.01):   8%|▊         | 67/800 [04:58<54:38,  4.47s/it]
#
#
# Gen. (-1.09) | Discrim. (-0.02):   8%|▊         | 67/800 [05:03<54:38,  4.47s/it]
#
#
# Gen. (-1.09) | Discrim. (-0.02):   8%|▊         | 68/800 [05:03<54:40,  4.48s/it]
#
#
# Gen. (-1.04) | Discrim. (-0.03):   8%|▊         | 68/800 [05:07<54:40,  4.48s/it]
#
#
# Gen. (-1.04) | Discrim. (-0.03):   9%|▊         | 69/800 [05:07<54:30,  4.47s/it]
#
#
# Gen. (-1.15) | Discrim. (-0.04):   9%|▊         | 69/800 [05:12<54:30,  4.47s/it]
#
#
# Gen. (-1.15) | Discrim. (-0.04):   9%|▉         | 70/800 [05:12<54:32,  4.48s/it]
#
#
# Gen. (-1.13) | Discrim. (0.01):   9%|▉         | 70/800 [05:16<54:32,  4.48s/it]
#
#
# Gen. (-1.13) | Discrim. (0.01):   9%|▉         | 71/800 [05:16<54:25,  4.48s/it]
#
#
# Gen. (-1.12) | Discrim. (0.01):   9%|▉         | 71/800 [05:21<54:25,  4.48s/it]
#
#
# Gen. (-1.12) | Discrim. (0.01):   9%|▉         | 72/800 [05:21<54:22,  4.48s/it]
#
#
# Gen. (-1.09) | Discrim. (0.00):   9%|▉         | 72/800 [05:25<54:22,  4.48s/it]
#
#
# Gen. (-1.09) | Discrim. (0.00):   9%|▉         | 73/800 [05:25<54:18,  4.48s/it]
#
#
# Gen. (-1.08) | Discrim. (0.02):   9%|▉         | 73/800 [05:30<54:18,  4.48s/it]
#
#
# Gen. (-1.08) | Discrim. (0.02):   9%|▉         | 74/800 [05:30<54:14,  4.48s/it]
#
#
# Gen. (-1.03) | Discrim. (0.02):   9%|▉         | 74/800 [05:34<54:14,  4.48s/it]
#
#
# Gen. (-1.03) | Discrim. (0.02):   9%|▉         | 75/800 [05:34<54:15,  4.49s/it]
#
#
# Gen. (-0.98) | Discrim. (0.01):   9%|▉         | 75/800 [05:39<54:15,  4.49s/it]
#
#
# Gen. (-0.98) | Discrim. (0.01):  10%|▉         | 76/800 [05:39<54:07,  4.49s/it]
#
#
# Gen. (-0.96) | Discrim. (0.00):  10%|▉         | 76/800 [05:43<54:07,  4.49s/it]
#
#
# Gen. (-0.96) | Discrim. (0.00):  10%|▉         | 77/800 [05:43<54:00,  4.48s/it]
#
#
# Gen. (-0.97) | Discrim. (-0.02):  10%|▉         | 77/800 [05:47<54:00,  4.48s/it]
#
#
# Gen. (-0.97) | Discrim. (-0.02):  10%|▉         | 78/800 [05:47<53:54,  4.48s/it]
#
#
# Gen. (-1.00) | Discrim. (0.01):  10%|▉         | 78/800 [05:52<53:54,  4.48s/it]
#
#
# Gen. (-1.00) | Discrim. (0.01):  10%|▉         | 79/800 [05:52<53:49,  4.48s/it]
#
#
# Gen. (-1.02) | Discrim. (-0.07):  10%|▉         | 79/800 [05:56<53:49,  4.48s/it]
#
#
# Gen. (-1.02) | Discrim. (-0.07):  10%|█         | 80/800 [05:56<53:42,  4.48s/it]
#
#
# Gen. (-1.10) | Discrim. (-0.06):  10%|█         | 80/800 [06:01<53:42,  4.48s/it]
#
#
# Gen. (-1.10) | Discrim. (-0.06):  10%|█         | 81/800 [06:01<53:43,  4.48s/it]
#
#
# Gen. (-1.07) | Discrim. (-0.05):  10%|█         | 81/800 [06:05<53:43,  4.48s/it]
#
#
# Gen. (-1.07) | Discrim. (-0.05):  10%|█         | 82/800 [06:05<53:37,  4.48s/it]
#
#
# Gen. (-1.10) | Discrim. (-0.08):  10%|█         | 82/800 [06:10<53:37,  4.48s/it]
#
#
# Gen. (-1.10) | Discrim. (-0.08):  10%|█         | 83/800 [06:10<53:34,  4.48s/it]
#
#
# Gen. (-1.05) | Discrim. (-0.00):  10%|█         | 83/800 [06:14<53:34,  4.48s/it]
#
#
# Gen. (-1.05) | Discrim. (-0.00):  10%|█         | 84/800 [06:14<53:28,  4.48s/it]
#
#
# Gen. (-1.08) | Discrim. (-0.03):  10%|█         | 84/800 [06:19<53:28,  4.48s/it]
#
#
# Gen. (-1.08) | Discrim. (-0.03):  11%|█         | 85/800 [06:19<53:22,  4.48s/it]
#
#
# Gen. (-1.08) | Discrim. (0.00):  11%|█         | 85/800 [06:23<53:22,  4.48s/it]
#
#
# Gen. (-1.08) | Discrim. (0.00):  11%|█         | 86/800 [06:23<53:19,  4.48s/it]
#
#
# Gen. (-1.07) | Discrim. (-0.02):  11%|█         | 86/800 [06:28<53:19,  4.48s/it]
#
#
# Gen. (-1.07) | Discrim. (-0.02):  11%|█         | 87/800 [06:28<53:15,  4.48s/it]
#
#
# Gen. (-1.06) | Discrim. (-0.02):  11%|█         | 87/800 [06:32<53:15,  4.48s/it]
#
#
# Gen. (-1.06) | Discrim. (-0.02):  11%|█         | 88/800 [06:32<53:10,  4.48s/it]
#
#
# Gen. (-1.02) | Discrim. (-0.03):  11%|█         | 88/800 [06:37<53:10,  4.48s/it]
#
#
# Gen. (-1.02) | Discrim. (-0.03):  11%|█         | 89/800 [06:37<53:07,  4.48s/it]
#
#
# Gen. (-1.10) | Discrim. (-0.07):  11%|█         | 89/800 [06:41<53:07,  4.48s/it]
#
#
# Gen. (-1.10) | Discrim. (-0.07):  11%|█▏        | 90/800 [06:41<53:00,  4.48s/it]
#
#
# Gen. (-1.08) | Discrim. (-0.06):  11%|█▏        | 90/800 [06:46<53:00,  4.48s/it]
#
#
# Gen. (-1.08) | Discrim. (-0.06):  11%|█▏        | 91/800 [06:46<52:56,  4.48s/it]
#
#
# Gen. (-1.06) | Discrim. (-0.05):  11%|█▏        | 91/800 [06:50<52:56,  4.48s/it]
#
#
# Gen. (-1.06) | Discrim. (-0.05):  12%|█▏        | 92/800 [06:50<52:51,  4.48s/it]
#
#
# Gen. (-1.01) | Discrim. (0.02):  12%|█▏        | 92/800 [06:55<52:51,  4.48s/it]
#
#
# Gen. (-1.01) | Discrim. (0.02):  12%|█▏        | 93/800 [06:55<52:45,  4.48s/it]
#
#
# Gen. (-0.98) | Discrim. (0.02):  12%|█▏        | 93/800 [06:59<52:45,  4.48s/it]
#
#
# Gen. (-0.98) | Discrim. (0.02):  12%|█▏        | 94/800 [06:59<52:40,  4.48s/it]
#
#
# Gen. (-1.03) | Discrim. (0.02):  12%|█▏        | 94/800 [07:04<52:40,  4.48s/it]
#
#
# Gen. (-1.03) | Discrim. (0.02):  12%|█▏        | 95/800 [07:04<52:38,  4.48s/it]
#
#
# Gen. (-1.04) | Discrim. (0.04):  12%|█▏        | 95/800 [07:08<52:38,  4.48s/it]
#
#
# Gen. (-1.04) | Discrim. (0.04):  12%|█▏        | 96/800 [07:08<52:34,  4.48s/it]
#
#
# Gen. (-1.11) | Discrim. (-0.07):  12%|█▏        | 96/800 [07:13<52:34,  4.48s/it]
#
#
# Gen. (-1.11) | Discrim. (-0.07):  12%|█▏        | 97/800 [07:13<52:30,  4.48s/it]
#
#
# Gen. (-1.01) | Discrim. (-0.01):  12%|█▏        | 97/800 [07:17<52:30,  4.48s/it]
#
#
# Gen. (-1.01) | Discrim. (-0.01):  12%|█▏        | 98/800 [07:17<52:25,  4.48s/it]
#
#
# Gen. (-1.09) | Discrim. (-0.06):  12%|█▏        | 98/800 [07:22<52:25,  4.48s/it]
#
#
# Gen. (-1.09) | Discrim. (-0.06):  12%|█▏        | 99/800 [07:22<52:24,  4.49s/it]
#
#
# Gen. (-1.02) | Discrim. (0.00):  12%|█▏        | 99/800 [07:26<52:24,  4.49s/it]
#
#
# Gen. (-1.02) | Discrim. (0.00):  12%|█▎        | 100/800 [07:26<52:19,  4.48s/it]
#
#
# Gen. (-0.99) | Discrim. (0.01):  12%|█▎        | 100/800 [07:31<52:19,  4.48s/it]
#
#
# Gen. (-0.99) | Discrim. (0.01):  13%|█▎        | 101/800 [07:31<52:14,  4.48s/it]
#
#
# Gen. (-0.90) | Discrim. (-0.04):  13%|█▎        | 101/800 [07:35<52:14,  4.48s/it]
#
#
# Gen. (-0.90) | Discrim. (-0.04):  13%|█▎        | 102/800 [07:35<52:11,  4.49s/it]
#
#
# Gen. (-0.89) | Discrim. (0.04):  13%|█▎        | 102/800 [07:40<52:11,  4.49s/it]
#
#
# Gen. (-0.89) | Discrim. (0.04):  13%|█▎        | 103/800 [07:40<52:08,  4.49s/it]
#
#
# Gen. (-0.81) | Discrim. (-0.02):  13%|█▎        | 103/800 [07:44<52:08,  4.49s/it]
#
#
# Gen. (-0.81) | Discrim. (-0.02):  13%|█▎        | 104/800 [07:44<51:59,  4.48s/it]
#
#
# Gen. (-0.70) | Discrim. (-0.01):  13%|█▎        | 104/800 [07:48<51:59,  4.48s/it]
#
#
# Gen. (-0.70) | Discrim. (-0.01):  13%|█▎        | 105/800 [07:48<51:49,  4.47s/it]
#
#
# Gen. (-0.67) | Discrim. (0.01):  13%|█▎        | 105/800 [07:53<51:49,  4.47s/it]
#
#
# Gen. (-0.67) | Discrim. (0.01):  13%|█▎        | 106/800 [07:53<51:40,  4.47s/it]
#
#
# Gen. (-0.71) | Discrim. (0.07):  13%|█▎        | 106/800 [07:57<51:40,  4.47s/it]
#
#
# Gen. (-0.71) | Discrim. (0.07):  13%|█▎        | 107/800 [07:57<51:31,  4.46s/it]
#
#
# Gen. (-0.63) | Discrim. (0.09):  13%|█▎        | 107/800 [08:02<51:31,  4.46s/it]
#
#
# Gen. (-0.63) | Discrim. (0.09):  14%|█▎        | 108/800 [08:02<51:23,  4.46s/it]
#
#
# Gen. (-0.68) | Discrim. (0.02):  14%|█▎        | 108/800 [08:06<51:23,  4.46s/it]
#
#
# Gen. (-0.68) | Discrim. (0.02):  14%|█▎        | 109/800 [08:06<51:17,  4.45s/it]
#
#
# Gen. (-0.72) | Discrim. (-0.09):  14%|█▎        | 109/800 [08:11<51:17,  4.45s/it]
#
#
# Gen. (-0.72) | Discrim. (-0.09):  14%|█▍        | 110/800 [08:11<51:13,  4.45s/it]
#
#
# Gen. (-0.67) | Discrim. (-0.12):  14%|█▍        | 110/800 [08:15<51:13,  4.45s/it]
#
#
# Gen. (-0.67) | Discrim. (-0.12):  14%|█▍        | 111/800 [08:15<51:06,  4.45s/it]
#
#
# Gen. (-0.66) | Discrim. (0.02):  14%|█▍        | 111/800 [08:20<51:06,  4.45s/it]
#
#
# Gen. (-0.66) | Discrim. (0.02):  14%|█▍        | 112/800 [08:20<50:58,  4.45s/it]
#
#
# Gen. (-0.61) | Discrim. (0.03):  14%|█▍        | 112/800 [08:24<50:58,  4.45s/it]
#
#
# Gen. (-0.61) | Discrim. (0.03):  14%|█▍        | 113/800 [08:24<50:58,  4.45s/it]
#
#
# Gen. (-0.66) | Discrim. (-0.13):  14%|█▍        | 113/800 [08:29<50:58,  4.45s/it]
#
#
# Gen. (-0.66) | Discrim. (-0.13):  14%|█▍        | 114/800 [08:29<50:52,  4.45s/it]
#
#
# Gen. (-0.58) | Discrim. (0.05):  14%|█▍        | 114/800 [08:33<50:52,  4.45s/it]
#
#
# Gen. (-0.58) | Discrim. (0.05):  14%|█▍        | 115/800 [08:33<50:48,  4.45s/it]
#
#
# Gen. (-0.49) | Discrim. (0.01):  14%|█▍        | 115/800 [08:37<50:48,  4.45s/it]
#
#
# Gen. (-0.49) | Discrim. (0.01):  14%|█▍        | 116/800 [08:37<50:45,  4.45s/it]
#
#
# Gen. (-0.49) | Discrim. (-0.12):  14%|█▍        | 116/800 [08:42<50:45,  4.45s/it]
#
#
# Gen. (-0.49) | Discrim. (-0.12):  15%|█▍        | 117/800 [08:42<50:41,  4.45s/it]
#
#
# Gen. (-0.49) | Discrim. (0.00):  15%|█▍        | 117/800 [08:46<50:41,  4.45s/it]
#
#
# Gen. (-0.49) | Discrim. (0.00):  15%|█▍        | 118/800 [08:46<50:33,  4.45s/it]
#
#
# Gen. (-0.56) | Discrim. (-0.08):  15%|█▍        | 118/800 [08:51<50:33,  4.45s/it]
#
#
# Gen. (-0.56) | Discrim. (-0.08):  15%|█▍        | 119/800 [08:51<50:28,  4.45s/it]
#
#
# Gen. (-0.60) | Discrim. (-0.03):  15%|█▍        | 119/800 [08:55<50:28,  4.45s/it]
#
#
# Gen. (-0.60) | Discrim. (-0.03):  15%|█▌        | 120/800 [08:55<50:23,  4.45s/it]
#
#
# Gen. (-0.49) | Discrim. (0.09):  15%|█▌        | 120/800 [09:00<50:23,  4.45s/it]
#
#
# Gen. (-0.49) | Discrim. (0.09):  15%|█▌        | 121/800 [09:00<50:18,  4.45s/it]
#
#
# Gen. (-0.66) | Discrim. (-0.15):  15%|█▌        | 121/800 [09:04<50:18,  4.45s/it]
#
#
# Gen. (-0.66) | Discrim. (-0.15):  15%|█▌        | 122/800 [09:04<50:13,  4.45s/it]
#
#
# Gen. (-0.64) | Discrim. (0.00):  15%|█▌        | 122/800 [09:09<50:13,  4.45s/it]
#
#
# Gen. (-0.64) | Discrim. (0.00):  15%|█▌        | 123/800 [09:09<50:11,  4.45s/it]
#
#
# Gen. (-0.64) | Discrim. (-0.09):  15%|█▌        | 123/800 [09:13<50:11,  4.45s/it]
#
#
# Gen. (-0.64) | Discrim. (-0.09):  16%|█▌        | 124/800 [09:13<50:07,  4.45s/it]
#
#
# Gen. (-0.55) | Discrim. (0.03):  16%|█▌        | 124/800 [09:17<50:07,  4.45s/it]
#
#
# Gen. (-0.55) | Discrim. (0.03):  16%|█▌        | 125/800 [09:17<50:01,  4.45s/it]
#
#
# Gen. (-0.53) | Discrim. (0.06):  16%|█▌        | 125/800 [09:22<50:01,  4.45s/it]
#
#
# Gen. (-0.53) | Discrim. (0.06):  16%|█▌        | 126/800 [09:22<49:59,  4.45s/it]
#
#
# Gen. (-0.44) | Discrim. (-0.11):  16%|█▌        | 126/800 [09:26<49:59,  4.45s/it]
#
#
# Gen. (-0.44) | Discrim. (-0.11):  16%|█▌        | 127/800 [09:26<49:59,  4.46s/it]
#
#
# Gen. (-0.49) | Discrim. (-0.00):  16%|█▌        | 127/800 [09:31<49:59,  4.46s/it]
#
#
# Gen. (-0.49) | Discrim. (-0.00):  16%|█▌        | 128/800 [09:31<50:02,  4.47s/it]
#
#
# Gen. (-0.63) | Discrim. (0.01):  16%|█▌        | 128/800 [09:35<50:02,  4.47s/it]
#
#
# Gen. (-0.63) | Discrim. (0.01):  16%|█▌        | 129/800 [09:35<50:01,  4.47s/it]
#
#
# Gen. (-0.48) | Discrim. (-0.01):  16%|█▌        | 129/800 [09:40<50:01,  4.47s/it]
#
#
# Gen. (-0.48) | Discrim. (-0.01):  16%|█▋        | 130/800 [09:40<50:01,  4.48s/it]
#
#
# Gen. (-0.55) | Discrim. (0.02):  16%|█▋        | 130/800 [09:44<50:01,  4.48s/it]
#
#
# Gen. (-0.55) | Discrim. (0.02):  16%|█▋        | 131/800 [09:44<49:56,  4.48s/it]
#
#
# Gen. (-0.59) | Discrim. (0.08):  16%|█▋        | 131/800 [09:49<49:56,  4.48s/it]
#
#
# Gen. (-0.59) | Discrim. (0.08):  16%|█▋        | 132/800 [09:49<49:45,  4.47s/it]
#
#
# Gen. (-0.69) | Discrim. (0.02):  16%|█▋        | 132/800 [09:53<49:45,  4.47s/it]
#
#
# Gen. (-0.69) | Discrim. (0.02):  17%|█▋        | 133/800 [09:53<49:39,  4.47s/it]
#
#
# Gen. (-0.57) | Discrim. (0.10):  17%|█▋        | 133/800 [09:58<49:39,  4.47s/it]
#
#
# Gen. (-0.57) | Discrim. (0.10):  17%|█▋        | 134/800 [09:58<49:32,  4.46s/it]
#
#
# Gen. (-0.51) | Discrim. (0.01):  17%|█▋        | 134/800 [10:02<49:32,  4.46s/it]
#
#
# Gen. (-0.51) | Discrim. (0.01):  17%|█▋        | 135/800 [10:02<49:25,  4.46s/it]
#
#
# Gen. (-0.47) | Discrim. (0.07):  17%|█▋        | 135/800 [10:07<49:25,  4.46s/it]
#
#
# Gen. (-0.47) | Discrim. (0.07):  17%|█▋        | 136/800 [10:07<49:19,  4.46s/it]
#
#
# Gen. (-0.58) | Discrim. (0.09):  17%|█▋        | 136/800 [10:11<49:19,  4.46s/it]
#
#
# Gen. (-0.58) | Discrim. (0.09):  17%|█▋        | 137/800 [10:11<49:15,  4.46s/it]
#
#
# Gen. (-0.42) | Discrim. (0.03):  17%|█▋        | 137/800 [10:15<49:15,  4.46s/it]
#
#
# Gen. (-0.42) | Discrim. (0.03):  17%|█▋        | 138/800 [10:15<49:10,  4.46s/it]
#
#
# Gen. (-0.63) | Discrim. (0.00):  17%|█▋        | 138/800 [10:20<49:10,  4.46s/it]
#
#
# Gen. (-0.63) | Discrim. (0.00):  17%|█▋        | 139/800 [10:20<49:04,  4.45s/it]
#
#
# Gen. (-0.54) | Discrim. (-0.00):  17%|█▋        | 139/800 [10:24<49:04,  4.45s/it]
#
#
# Gen. (-0.54) | Discrim. (-0.00):  18%|█▊        | 140/800 [10:24<49:16,  4.48s/it]
#
#
# Gen. (-0.55) | Discrim. (0.01):  18%|█▊        | 140/800 [10:29<49:16,  4.48s/it]
#
#
# Gen. (-0.55) | Discrim. (0.01):  18%|█▊        | 141/800 [10:29<49:21,  4.49s/it]
#
#
# Gen. (-0.66) | Discrim. (-0.03):  18%|█▊        | 141/800 [10:34<49:21,  4.49s/it]
#
#
# Gen. (-0.66) | Discrim. (-0.03):  18%|█▊        | 142/800 [10:34<49:24,  4.50s/it]
#
#
# Gen. (-0.43) | Discrim. (0.07):  18%|█▊        | 142/800 [10:38<49:24,  4.50s/it]
#
#
# Gen. (-0.43) | Discrim. (0.07):  18%|█▊        | 143/800 [10:38<49:24,  4.51s/it]
#
#
# Gen. (-0.47) | Discrim. (0.04):  18%|█▊        | 143/800 [10:43<49:24,  4.51s/it]
#
#
# Gen. (-0.47) | Discrim. (0.04):  18%|█▊        | 144/800 [10:43<49:23,  4.52s/it]
#
#
# Gen. (-0.45) | Discrim. (-0.06):  18%|█▊        | 144/800 [10:47<49:23,  4.52s/it]
#
#
# Gen. (-0.45) | Discrim. (-0.06):  18%|█▊        | 145/800 [10:47<49:19,  4.52s/it]
#
#
# Gen. (-0.37) | Discrim. (-0.22):  18%|█▊        | 145/800 [10:52<49:19,  4.52s/it]
#
#
# Gen. (-0.37) | Discrim. (-0.22):  18%|█▊        | 146/800 [10:52<49:19,  4.53s/it]
#
#
# Gen. (-0.40) | Discrim. (0.05):  18%|█▊        | 146/800 [10:56<49:19,  4.53s/it]
#
#
# Gen. (-0.40) | Discrim. (0.05):  18%|█▊        | 147/800 [10:56<49:15,  4.53s/it]
#
#
# Gen. (-0.57) | Discrim. (0.12):  18%|█▊        | 147/800 [11:01<49:15,  4.53s/it]
#
#
# Gen. (-0.57) | Discrim. (0.12):  18%|█▊        | 148/800 [11:01<49:10,  4.52s/it]
#
#
# Gen. (-0.62) | Discrim. (0.06):  18%|█▊        | 148/800 [11:05<49:10,  4.52s/it]
#
#
# Gen. (-0.62) | Discrim. (0.06):  19%|█▊        | 149/800 [11:05<49:07,  4.53s/it]
#
#
# Gen. (-0.51) | Discrim. (-0.00):  19%|█▊        | 149/800 [11:10<49:07,  4.53s/it]
#
#
# Gen. (-0.51) | Discrim. (-0.00):  19%|█▉        | 150/800 [11:10<49:01,  4.53s/it]
#
#
# Gen. (-0.53) | Discrim. (0.05):  19%|█▉        | 150/800 [11:14<49:01,  4.53s/it]
#
#
# Gen. (-0.53) | Discrim. (0.05):  19%|█▉        | 151/800 [11:14<48:57,  4.53s/it]
#
#
# Gen. (-0.65) | Discrim. (0.00):  19%|█▉        | 151/800 [11:19<48:57,  4.53s/it]
#
#
# Gen. (-0.65) | Discrim. (0.00):  19%|█▉        | 152/800 [11:19<48:52,  4.53s/it]
#
#
# Gen. (-0.58) | Discrim. (-0.06):  19%|█▉        | 152/800 [11:23<48:52,  4.53s/it]
#
#
# Gen. (-0.58) | Discrim. (-0.06):  19%|█▉        | 153/800 [11:23<48:46,  4.52s/it]
#
#
# Gen. (-0.48) | Discrim. (-0.02):  19%|█▉        | 153/800 [11:28<48:46,  4.52s/it]
#
#
# Gen. (-0.48) | Discrim. (-0.02):  19%|█▉        | 154/800 [11:28<48:41,  4.52s/it]
#
#
# Gen. (-0.60) | Discrim. (-0.16):  19%|█▉        | 154/800 [11:32<48:41,  4.52s/it]
#
#
# Gen. (-0.60) | Discrim. (-0.16):  19%|█▉        | 155/800 [11:32<48:26,  4.51s/it]
#
#
# Gen. (-0.62) | Discrim. (-0.08):  19%|█▉        | 155/800 [11:37<48:26,  4.51s/it]
#
#
# Gen. (-0.62) | Discrim. (-0.08):  20%|█▉        | 156/800 [11:37<48:09,  4.49s/it]
#
#
# Gen. (-0.56) | Discrim. (-0.01):  20%|█▉        | 156/800 [11:41<48:09,  4.49s/it]
#
#
# Gen. (-0.56) | Discrim. (-0.01):  20%|█▉        | 157/800 [11:41<47:57,  4.47s/it]
#
#
# Gen. (-0.57) | Discrim. (-0.03):  20%|█▉        | 157/800 [11:46<47:57,  4.47s/it]
#
#
# Gen. (-0.57) | Discrim. (-0.03):  20%|█▉        | 158/800 [11:46<47:48,  4.47s/it]
#
#
# Gen. (-0.37) | Discrim. (0.05):  20%|█▉        | 158/800 [11:50<47:48,  4.47s/it]
#
#
# Gen. (-0.37) | Discrim. (0.05):  20%|█▉        | 159/800 [11:50<47:39,  4.46s/it]
#
#
# Gen. (-0.50) | Discrim. (-0.11):  20%|█▉        | 159/800 [11:55<47:39,  4.46s/it]
#
#
# Gen. (-0.50) | Discrim. (-0.11):  20%|██        | 160/800 [11:55<47:31,  4.46s/it]
#
#
# Gen. (-0.52) | Discrim. (0.12):  20%|██        | 160/800 [11:59<47:31,  4.46s/it]
#
#
# Gen. (-0.52) | Discrim. (0.12):  20%|██        | 161/800 [11:59<47:27,  4.46s/it]
#
#
# Gen. (-0.55) | Discrim. (0.03):  20%|██        | 161/800 [12:03<47:27,  4.46s/it]
#
#
# Gen. (-0.55) | Discrim. (0.03):  20%|██        | 162/800 [12:03<47:20,  4.45s/it]
#
#
# Gen. (-0.59) | Discrim. (-0.05):  20%|██        | 162/800 [12:08<47:20,  4.45s/it]
#
#
# Gen. (-0.59) | Discrim. (-0.05):  20%|██        | 163/800 [12:08<47:15,  4.45s/it]
#
#
# Gen. (-0.49) | Discrim. (-0.03):  20%|██        | 163/800 [12:12<47:15,  4.45s/it]
#
#
# Gen. (-0.49) | Discrim. (-0.03):  20%|██        | 164/800 [12:12<47:10,  4.45s/it]
#
#
# Gen. (-0.35) | Discrim. (0.03):  20%|██        | 164/800 [12:17<47:10,  4.45s/it]
#
#
# Gen. (-0.35) | Discrim. (0.03):  21%|██        | 165/800 [12:17<47:04,  4.45s/it]
#
#
# Gen. (-0.52) | Discrim. (-0.01):  21%|██        | 165/800 [12:21<47:04,  4.45s/it]
#
#
# Gen. (-0.52) | Discrim. (-0.01):  21%|██        | 166/800 [12:21<46:59,  4.45s/it]
#
#
# Gen. (-0.35) | Discrim. (0.07):  21%|██        | 166/800 [12:26<46:59,  4.45s/it]
#
#
# Gen. (-0.35) | Discrim. (0.07):  21%|██        | 167/800 [12:26<46:57,  4.45s/it]
#
#
# Gen. (-0.58) | Discrim. (-0.10):  21%|██        | 167/800 [12:30<46:57,  4.45s/it]
#
#
# Gen. (-0.58) | Discrim. (-0.10):  21%|██        | 168/800 [12:30<46:53,  4.45s/it]
#
#
# Gen. (-0.51) | Discrim. (0.07):  21%|██        | 168/800 [12:35<46:53,  4.45s/it]
#
#
# Gen. (-0.51) | Discrim. (0.07):  21%|██        | 169/800 [12:35<46:47,  4.45s/it]
#
#
# Gen. (-0.45) | Discrim. (-0.05):  21%|██        | 169/800 [12:39<46:47,  4.45s/it]
#
#
# Gen. (-0.45) | Discrim. (-0.05):  21%|██▏       | 170/800 [12:39<46:43,  4.45s/it]
#
#
# Gen. (-0.62) | Discrim. (0.01):  21%|██▏       | 170/800 [12:43<46:43,  4.45s/it]
#
#
# Gen. (-0.62) | Discrim. (0.01):  21%|██▏       | 171/800 [12:43<46:38,  4.45s/it]
#
#
# Gen. (-0.31) | Discrim. (-0.09):  21%|██▏       | 171/800 [12:48<46:38,  4.45s/it]
#
#
# Gen. (-0.31) | Discrim. (-0.09):  22%|██▏       | 172/800 [12:48<46:32,  4.45s/it]
#
#
# Gen. (-0.36) | Discrim. (0.05):  22%|██▏       | 172/800 [12:52<46:32,  4.45s/it]
#
#
# Gen. (-0.36) | Discrim. (0.05):  22%|██▏       | 173/800 [12:52<46:29,  4.45s/it]
#
#
# Gen. (-0.48) | Discrim. (-0.05):  22%|██▏       | 173/800 [12:57<46:29,  4.45s/it]
#
#
# Gen. (-0.48) | Discrim. (-0.05):  22%|██▏       | 174/800 [12:57<46:25,  4.45s/it]
#
#
# Gen. (-0.24) | Discrim. (-0.07):  22%|██▏       | 174/800 [13:01<46:25,  4.45s/it]
#
#
# Gen. (-0.24) | Discrim. (-0.07):  22%|██▏       | 175/800 [13:01<46:19,  4.45s/it]
#
#
# Gen. (-0.32) | Discrim. (0.09):  22%|██▏       | 175/800 [13:06<46:19,  4.45s/it]
#
#
# Gen. (-0.32) | Discrim. (0.09):  22%|██▏       | 176/800 [13:06<46:17,  4.45s/it]
#
#
# Gen. (-0.54) | Discrim. (0.20):  22%|██▏       | 176/800 [13:10<46:17,  4.45s/it]
#
#
# Gen. (-0.54) | Discrim. (0.20):  22%|██▏       | 177/800 [13:10<46:13,  4.45s/it]
#
#
# Gen. (-0.40) | Discrim. (0.04):  22%|██▏       | 177/800 [13:15<46:13,  4.45s/it]
#
#
# Gen. (-0.40) | Discrim. (0.04):  22%|██▏       | 178/800 [13:15<46:09,  4.45s/it]
#
#
# Gen. (-0.21) | Discrim. (0.03):  22%|██▏       | 178/800 [13:19<46:09,  4.45s/it]
#
#
# Gen. (-0.21) | Discrim. (0.03):  22%|██▏       | 179/800 [13:19<46:06,  4.45s/it]
#
#
# Gen. (-0.42) | Discrim. (0.04):  22%|██▏       | 179/800 [13:24<46:06,  4.45s/it]
#
#
# Gen. (-0.42) | Discrim. (0.04):  22%|██▎       | 180/800 [13:24<46:00,  4.45s/it]
#
#
# Gen. (-0.35) | Discrim. (0.02):  22%|██▎       | 180/800 [13:28<46:00,  4.45s/it]
#
#
# Gen. (-0.35) | Discrim. (0.02):  23%|██▎       | 181/800 [13:28<45:56,  4.45s/it]
#
#
# Gen. (-0.34) | Discrim. (0.23):  23%|██▎       | 181/800 [13:32<45:56,  4.45s/it]
#
#
# Gen. (-0.34) | Discrim. (0.23):  23%|██▎       | 182/800 [13:32<45:54,  4.46s/it]
#
#
# Gen. (-0.37) | Discrim. (-0.05):  23%|██▎       | 182/800 [13:37<45:54,  4.46s/it]
#
#
# Gen. (-0.37) | Discrim. (-0.05):  23%|██▎       | 183/800 [13:37<45:47,  4.45s/it]
#
#
# Gen. (-0.26) | Discrim. (0.04):  23%|██▎       | 183/800 [13:41<45:47,  4.45s/it]
#
#
# Gen. (-0.26) | Discrim. (0.04):  23%|██▎       | 184/800 [13:41<45:42,  4.45s/it]
#
#
# Gen. (-0.33) | Discrim. (0.01):  23%|██▎       | 184/800 [13:46<45:42,  4.45s/it]
#
#
# Gen. (-0.33) | Discrim. (0.01):  23%|██▎       | 185/800 [13:46<45:39,  4.45s/it]
#
#
# Gen. (-0.24) | Discrim. (0.03):  23%|██▎       | 185/800 [13:50<45:39,  4.45s/it]
#
#
# Gen. (-0.24) | Discrim. (0.03):  23%|██▎       | 186/800 [13:50<45:32,  4.45s/it]
#
#
# Gen. (-0.25) | Discrim. (0.09):  23%|██▎       | 186/800 [13:55<45:32,  4.45s/it]
#
#
# Gen. (-0.25) | Discrim. (0.09):  23%|██▎       | 187/800 [13:55<45:28,  4.45s/it]
#
#
# Gen. (-0.22) | Discrim. (0.05):  23%|██▎       | 187/800 [13:59<45:28,  4.45s/it]
#
#
# Gen. (-0.22) | Discrim. (0.05):  24%|██▎       | 188/800 [13:59<45:24,  4.45s/it]
#
#
# Gen. (-0.20) | Discrim. (-0.13):  24%|██▎       | 188/800 [14:04<45:24,  4.45s/it]
#
#
# Gen. (-0.20) | Discrim. (-0.13):  24%|██▎       | 189/800 [14:04<45:24,  4.46s/it]
#
#
# Gen. (-0.13) | Discrim. (-0.04):  24%|██▎       | 189/800 [14:08<45:24,  4.46s/it]
#
#
# Gen. (-0.13) | Discrim. (-0.04):  24%|██▍       | 190/800 [14:08<45:22,  4.46s/it]
#
#
# Gen. (-0.15) | Discrim. (-0.10):  24%|██▍       | 190/800 [14:13<45:22,  4.46s/it]
#
#
# Gen. (-0.15) | Discrim. (-0.10):  24%|██▍       | 191/800 [14:13<45:27,  4.48s/it]
#
#
# Gen. (-0.08) | Discrim. (-0.15):  24%|██▍       | 191/800 [14:17<45:27,  4.48s/it]
#
#
# Gen. (-0.08) | Discrim. (-0.15):  24%|██▍       | 192/800 [14:17<45:28,  4.49s/it]
#
#
# Gen. (-0.24) | Discrim. (0.02):  24%|██▍       | 192/800 [14:22<45:28,  4.49s/it]
#
#
# Gen. (-0.24) | Discrim. (0.02):  24%|██▍       | 193/800 [14:22<45:24,  4.49s/it]
#
#
# Gen. (-0.20) | Discrim. (0.05):  24%|██▍       | 193/800 [14:26<45:24,  4.49s/it]
#
#
# Gen. (-0.20) | Discrim. (0.05):  24%|██▍       | 194/800 [14:26<45:25,  4.50s/it]
#
#
# Gen. (-0.10) | Discrim. (-0.06):  24%|██▍       | 194/800 [14:31<45:25,  4.50s/it]
#
#
# Gen. (-0.10) | Discrim. (-0.06):  24%|██▍       | 195/800 [14:31<45:21,  4.50s/it]
#
#
# Gen. (-0.14) | Discrim. (0.03):  24%|██▍       | 195/800 [14:35<45:21,  4.50s/it]
#
#
# Gen. (-0.14) | Discrim. (0.03):  24%|██▍       | 196/800 [14:35<45:18,  4.50s/it]
#
#
# Gen. (-0.18) | Discrim. (0.06):  24%|██▍       | 196/800 [14:40<45:18,  4.50s/it]
#
#
# Gen. (-0.18) | Discrim. (0.06):  25%|██▍       | 197/800 [14:40<45:17,  4.51s/it]
#
#
# Gen. (-0.19) | Discrim. (-0.16):  25%|██▍       | 197/800 [14:44<45:17,  4.51s/it]
#
#
# Gen. (-0.19) | Discrim. (-0.16):  25%|██▍       | 198/800 [14:44<45:13,  4.51s/it]
#
#
# Gen. (-0.11) | Discrim. (0.03):  25%|██▍       | 198/800 [14:49<45:13,  4.51s/it]
#
#
# Gen. (-0.11) | Discrim. (0.03):  25%|██▍       | 199/800 [14:49<45:06,  4.50s/it]
#
#
# Gen. (-0.31) | Discrim. (0.19):  25%|██▍       | 199/800 [14:53<45:06,  4.50s/it]
#
#
# Gen. (-0.31) | Discrim. (0.19):  25%|██▌       | 200/800 [14:53<44:55,  4.49s/it]
#
#
# Gen. (-0.24) | Discrim. (-0.22):  25%|██▌       | 200/800 [14:58<44:55,  4.49s/it]
#
#
# Gen. (-0.24) | Discrim. (-0.22):  25%|██▌       | 201/800 [14:58<44:42,  4.48s/it]
#
#
# Gen. (-0.12) | Discrim. (-0.10):  25%|██▌       | 201/800 [15:02<44:42,  4.48s/it]
#
#
# Gen. (-0.12) | Discrim. (-0.10):  25%|██▌       | 202/800 [15:02<44:36,  4.48s/it]
#
#
# Gen. (-0.09) | Discrim. (-0.05):  25%|██▌       | 202/800 [15:07<44:36,  4.48s/it]
#
#
# Gen. (-0.09) | Discrim. (-0.05):  25%|██▌       | 203/800 [15:07<44:30,  4.47s/it]
#
#
# Gen. (-0.25) | Discrim. (0.08):  25%|██▌       | 203/800 [15:11<44:30,  4.47s/it]
#
#
# Gen. (-0.25) | Discrim. (0.08):  26%|██▌       | 204/800 [15:11<44:22,  4.47s/it]
#
#
# Gen. (-0.11) | Discrim. (-0.16):  26%|██▌       | 204/800 [15:15<44:22,  4.47s/it]
#
#
# Gen. (-0.11) | Discrim. (-0.16):  26%|██▌       | 205/800 [15:15<44:15,  4.46s/it]
#
#
# Gen. (-0.33) | Discrim. (0.17):  26%|██▌       | 205/800 [15:20<44:15,  4.46s/it]
#
#
# Gen. (-0.33) | Discrim. (0.17):  26%|██▌       | 206/800 [15:20<44:10,  4.46s/it]
#
#
# Gen. (-0.22) | Discrim. (-0.22):  26%|██▌       | 206/800 [15:24<44:10,  4.46s/it]
#
#
# Gen. (-0.22) | Discrim. (-0.22):  26%|██▌       | 207/800 [15:24<44:05,  4.46s/it]
#
#
# Gen. (-0.23) | Discrim. (0.12):  26%|██▌       | 207/800 [15:29<44:05,  4.46s/it]
#
#
# Gen. (-0.23) | Discrim. (0.12):  26%|██▌       | 208/800 [15:29<43:59,  4.46s/it]
#
#
# Gen. (-0.08) | Discrim. (0.10):  26%|██▌       | 208/800 [15:33<43:59,  4.46s/it]
#
#
# Gen. (-0.08) | Discrim. (0.10):  26%|██▌       | 209/800 [15:33<43:54,  4.46s/it]
#
#
# Gen. (-0.36) | Discrim. (-0.04):  26%|██▌       | 209/800 [15:38<43:54,  4.46s/it]
#
#
# Gen. (-0.36) | Discrim. (-0.04):  26%|██▋       | 210/800 [15:38<43:49,  4.46s/it]
#
#
# Gen. (-0.19) | Discrim. (0.18):  26%|██▋       | 210/800 [15:42<43:49,  4.46s/it]
#
#
# Gen. (-0.19) | Discrim. (0.18):  26%|██▋       | 211/800 [15:42<43:43,  4.45s/it]
#
#
# Gen. (-0.22) | Discrim. (-0.12):  26%|██▋       | 211/800 [15:47<43:43,  4.45s/it]
#
#
# Gen. (-0.22) | Discrim. (-0.12):  26%|██▋       | 212/800 [15:47<43:39,  4.46s/it]
#
#
# Gen. (-0.30) | Discrim. (0.18):  26%|██▋       | 212/800 [15:51<43:39,  4.46s/it]
#
#
# Gen. (-0.30) | Discrim. (0.18):  27%|██▋       | 213/800 [15:51<43:33,  4.45s/it]
#
#
# Gen. (-0.31) | Discrim. (-0.08):  27%|██▋       | 213/800 [15:56<43:33,  4.45s/it]
#
#
# Gen. (-0.31) | Discrim. (-0.08):  27%|██▋       | 214/800 [15:56<43:28,  4.45s/it]
#
#
# Gen. (-0.44) | Discrim. (-0.01):  27%|██▋       | 214/800 [16:00<43:28,  4.45s/it]
#
#
# Gen. (-0.44) | Discrim. (-0.01):  27%|██▋       | 215/800 [16:00<43:24,  4.45s/it]
#
#
# Gen. (-0.29) | Discrim. (-0.03):  27%|██▋       | 215/800 [16:04<43:24,  4.45s/it]
#
#
# Gen. (-0.29) | Discrim. (-0.03):  27%|██▋       | 216/800 [16:04<43:19,  4.45s/it]
#
#
# Gen. (-0.26) | Discrim. (-0.01):  27%|██▋       | 216/800 [16:09<43:19,  4.45s/it]
#
#
# Gen. (-0.26) | Discrim. (-0.01):  27%|██▋       | 217/800 [16:09<43:15,  4.45s/it]
#
#
# Gen. (-0.24) | Discrim. (0.03):  27%|██▋       | 217/800 [16:13<43:15,  4.45s/it]
#
#
# Gen. (-0.24) | Discrim. (0.03):  27%|██▋       | 218/800 [16:13<43:11,  4.45s/it]
#
#
# Gen. (-0.26) | Discrim. (0.10):  27%|██▋       | 218/800 [16:18<43:11,  4.45s/it]
#
#
# Gen. (-0.26) | Discrim. (0.10):  27%|██▋       | 219/800 [16:18<43:05,  4.45s/it]
#
#
# Gen. (-0.14) | Discrim. (-0.21):  27%|██▋       | 219/800 [16:22<43:05,  4.45s/it]
#
#
# Gen. (-0.14) | Discrim. (-0.21):  28%|██▊       | 220/800 [16:22<42:57,  4.44s/it]
#
#
# Gen. (-0.49) | Discrim. (-0.07):  28%|██▊       | 220/800 [16:27<42:57,  4.44s/it]
#
#
# Gen. (-0.49) | Discrim. (-0.07):  28%|██▊       | 221/800 [16:27<42:55,  4.45s/it]
#
#
# Gen. (-0.12) | Discrim. (-0.05):  28%|██▊       | 221/800 [16:31<42:55,  4.45s/it]
#
#
# Gen. (-0.12) | Discrim. (-0.05):  28%|██▊       | 222/800 [16:31<42:49,  4.45s/it]
#
#
# Gen. (-0.21) | Discrim. (-0.01):  28%|██▊       | 222/800 [16:36<42:49,  4.45s/it]
#
#
# Gen. (-0.21) | Discrim. (-0.01):  28%|██▊       | 223/800 [16:36<42:45,  4.45s/it]
#
#
# Gen. (-0.15) | Discrim. (0.08):  28%|██▊       | 223/800 [16:40<42:45,  4.45s/it]
#
#
# Gen. (-0.15) | Discrim. (0.08):  28%|██▊       | 224/800 [16:40<42:41,  4.45s/it]
#
#
# Gen. (0.10) | Discrim. (-0.15):  28%|██▊       | 224/800 [16:44<42:41,  4.45s/it]
#
#
# Gen. (0.10) | Discrim. (-0.15):  28%|██▊       | 225/800 [16:44<42:36,  4.45s/it]
#
#
# Gen. (-0.33) | Discrim. (0.10):  28%|██▊       | 225/800 [16:49<42:36,  4.45s/it]
#
#
# Gen. (-0.33) | Discrim. (0.10):  28%|██▊       | 226/800 [16:49<42:32,  4.45s/it]
#
#
# Gen. (-0.02) | Discrim. (-0.02):  28%|██▊       | 226/800 [16:53<42:32,  4.45s/it]
#
#
# Gen. (-0.02) | Discrim. (-0.02):  28%|██▊       | 227/800 [16:53<42:28,  4.45s/it]
#
#
# Gen. (0.08) | Discrim. (0.06):  28%|██▊       | 227/800 [16:58<42:28,  4.45s/it]
#
#
# Gen. (0.08) | Discrim. (0.06):  28%|██▊       | 228/800 [16:58<42:24,  4.45s/it]
#
#
# Gen. (-0.16) | Discrim. (-0.08):  28%|██▊       | 228/800 [17:02<42:24,  4.45s/it]
#
#
# Gen. (-0.16) | Discrim. (-0.08):  29%|██▊       | 229/800 [17:02<42:20,  4.45s/it]
#
#
# Gen. (-0.29) | Discrim. (-0.01):  29%|██▊       | 229/800 [17:07<42:20,  4.45s/it]
#
#
# Gen. (-0.29) | Discrim. (-0.01):  29%|██▉       | 230/800 [17:07<42:19,  4.46s/it]
#
#
# Gen. (-0.37) | Discrim. (-0.07):  29%|██▉       | 230/800 [17:11<42:19,  4.46s/it]
#
#
# Gen. (-0.37) | Discrim. (-0.07):  29%|██▉       | 231/800 [17:11<42:11,  4.45s/it]
#
#
# Gen. (-0.18) | Discrim. (0.10):  29%|██▉       | 231/800 [17:16<42:11,  4.45s/it]
#
#
# Gen. (-0.18) | Discrim. (0.10):  29%|██▉       | 232/800 [17:16<42:08,  4.45s/it]
#
#
# Gen. (-0.35) | Discrim. (0.17):  29%|██▉       | 232/800 [17:20<42:08,  4.45s/it]
#
#
# Gen. (-0.35) | Discrim. (0.17):  29%|██▉       | 233/800 [17:20<42:05,  4.45s/it]
#
#
# Gen. (-0.37) | Discrim. (0.15):  29%|██▉       | 233/800 [17:25<42:05,  4.45s/it]
#
#
# Gen. (-0.37) | Discrim. (0.15):  29%|██▉       | 234/800 [17:25<41:59,  4.45s/it]
#
#
# Gen. (-0.20) | Discrim. (-0.02):  29%|██▉       | 234/800 [17:29<41:59,  4.45s/it]
#
#
# Gen. (-0.20) | Discrim. (-0.02):  29%|██▉       | 235/800 [17:29<41:54,  4.45s/it]
#
#
# Gen. (-0.35) | Discrim. (-0.01):  29%|██▉       | 235/800 [17:33<41:54,  4.45s/it]
#
#
# Gen. (-0.35) | Discrim. (-0.01):  30%|██▉       | 236/800 [17:33<41:50,  4.45s/it]
#
#
# Gen. (-0.39) | Discrim. (0.01):  30%|██▉       | 236/800 [17:38<41:50,  4.45s/it]
#
#
# Gen. (-0.39) | Discrim. (0.01):  30%|██▉       | 237/800 [17:38<41:45,  4.45s/it]
#
#
# Gen. (-0.19) | Discrim. (0.07):  30%|██▉       | 237/800 [17:42<41:45,  4.45s/it]
#
#
# Gen. (-0.19) | Discrim. (0.07):  30%|██▉       | 238/800 [17:42<41:38,  4.45s/it]
#
#
# Gen. (-0.41) | Discrim. (0.03):  30%|██▉       | 238/800 [17:47<41:38,  4.45s/it]
#
#
# Gen. (-0.41) | Discrim. (0.03):  30%|██▉       | 239/800 [17:47<41:35,  4.45s/it]
#
#
# Gen. (-0.21) | Discrim. (0.05):  30%|██▉       | 239/800 [17:51<41:35,  4.45s/it]
#
#
# Gen. (-0.21) | Discrim. (0.05):  30%|███       | 240/800 [17:51<41:29,  4.45s/it]
#
#
# Gen. (-0.29) | Discrim. (-0.02):  30%|███       | 240/800 [17:56<41:29,  4.45s/it]
#
#
# Gen. (-0.29) | Discrim. (-0.02):  30%|███       | 241/800 [17:56<41:26,  4.45s/it]
#
#
# Gen. (-0.38) | Discrim. (-0.11):  30%|███       | 241/800 [18:00<41:26,  4.45s/it]
#
#
# Gen. (-0.38) | Discrim. (-0.11):  30%|███       | 242/800 [18:00<41:22,  4.45s/it]
#
#
# Gen. (-0.31) | Discrim. (-0.03):  30%|███       | 242/800 [18:05<41:22,  4.45s/it]
#
#
# Gen. (-0.31) | Discrim. (-0.03):  30%|███       | 243/800 [18:05<41:16,  4.45s/it]
#
#
# Gen. (-0.34) | Discrim. (-0.09):  30%|███       | 243/800 [18:09<41:16,  4.45s/it]
#
#
# Gen. (-0.34) | Discrim. (-0.09):  30%|███       | 244/800 [18:09<41:12,  4.45s/it]
#
#
# Gen. (-0.48) | Discrim. (0.05):  30%|███       | 244/800 [18:13<41:12,  4.45s/it]
#
#
# Gen. (-0.48) | Discrim. (0.05):  31%|███       | 245/800 [18:13<41:08,  4.45s/it]
#
#
# Gen. (-0.42) | Discrim. (0.03):  31%|███       | 245/800 [18:18<41:08,  4.45s/it]
#
#
# Gen. (-0.42) | Discrim. (0.03):  31%|███       | 246/800 [18:18<41:04,  4.45s/it]
#
#
# Gen. (-0.51) | Discrim. (-0.05):  31%|███       | 246/800 [18:22<41:04,  4.45s/it]
#
#
# Gen. (-0.51) | Discrim. (-0.05):  31%|███       | 247/800 [18:22<40:59,  4.45s/it]
#
#
# Gen. (-0.48) | Discrim. (0.03):  31%|███       | 247/800 [18:27<40:59,  4.45s/it]
#
#
# Gen. (-0.48) | Discrim. (0.03):  31%|███       | 248/800 [18:27<40:55,  4.45s/it]
#
#
# Gen. (-0.40) | Discrim. (-0.04):  31%|███       | 248/800 [18:31<40:55,  4.45s/it]
#
#
# Gen. (-0.40) | Discrim. (-0.04):  31%|███       | 249/800 [18:31<40:50,  4.45s/it]
#
#
# Gen. (-0.44) | Discrim. (-0.06):  31%|███       | 249/800 [18:36<40:50,  4.45s/it]
#
#
# Gen. (-0.44) | Discrim. (-0.06):  31%|███▏      | 250/800 [18:36<40:47,  4.45s/it]
#
#
# Gen. (-0.25) | Discrim. (-0.01):  31%|███▏      | 250/800 [18:40<40:47,  4.45s/it]
#
#
# Gen. (-0.25) | Discrim. (-0.01):  31%|███▏      | 251/800 [18:40<40:43,  4.45s/it]
#
#
# Gen. (-0.41) | Discrim. (-0.06):  31%|███▏      | 251/800 [18:45<40:43,  4.45s/it]
#
#
# Gen. (-0.41) | Discrim. (-0.06):  32%|███▏      | 252/800 [18:45<40:37,  4.45s/it]
#
#
# Gen. (-0.27) | Discrim. (0.03):  32%|███▏      | 252/800 [18:49<40:37,  4.45s/it]
#
#
# Gen. (-0.27) | Discrim. (0.03):  32%|███▏      | 253/800 [18:49<40:32,  4.45s/it]
#
#
# Gen. (-0.29) | Discrim. (0.01):  32%|███▏      | 253/800 [18:53<40:32,  4.45s/it]
#
#
# Gen. (-0.29) | Discrim. (0.01):  32%|███▏      | 254/800 [18:53<40:29,  4.45s/it]
#
#
# Gen. (-0.23) | Discrim. (0.05):  32%|███▏      | 254/800 [18:58<40:29,  4.45s/it]
#
#
# Gen. (-0.23) | Discrim. (0.05):  32%|███▏      | 255/800 [18:58<40:23,  4.45s/it]
#
#
# Gen. (-0.21) | Discrim. (0.05):  32%|███▏      | 255/800 [19:02<40:23,  4.45s/it]
#
#
# Gen. (-0.21) | Discrim. (0.05):  32%|███▏      | 256/800 [19:02<40:18,  4.45s/it]
#
#
# Gen. (-0.16) | Discrim. (0.07):  32%|███▏      | 256/800 [19:07<40:18,  4.45s/it]
#
#
# Gen. (-0.16) | Discrim. (0.07):  32%|███▏      | 257/800 [19:07<40:16,  4.45s/it]
#
#
# Gen. (-0.15) | Discrim. (0.01):  32%|███▏      | 257/800 [19:11<40:16,  4.45s/it]
#
#
# Gen. (-0.15) | Discrim. (0.01):  32%|███▏      | 258/800 [19:11<40:08,  4.44s/it]
#
#
# Gen. (-0.28) | Discrim. (-0.04):  32%|███▏      | 258/800 [19:16<40:08,  4.44s/it]
#
#
# Gen. (-0.28) | Discrim. (-0.04):  32%|███▏      | 259/800 [19:16<40:01,  4.44s/it]

# %% [markdown]
# ## Attempt 4: Give up and run for 200 epochs

# %%
from pathlib import Path
from typing import Tuple

import pandas as pd
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import Metadata


def train_ctgan(
    df_slice: pd.DataFrame,
    *,
    service_code: str,
    epochs: int = 200,
    outdir: Path = Path("checkpoints_3/models"),
) -> Tuple[CTGANSynthesizer, Path]:
    """Train a CTGAN for a fixed number of epochs and save the model."""

    outdir.mkdir(parents=True, exist_ok=True)

    # Build table metadata for the slice
    metadata = Metadata.detect_from_dataframes({"table": df_slice})

    # Configure and fit CTGAN
    synth = CTGANSynthesizer(
        metadata,
        epochs=epochs,
        batch_size=1024,
        pac=8,
        embedding_dim=128,
        generator_dim=(256, 256),
        discriminator_dim=(256, 256),
        generator_lr=2e-4,
        discriminator_lr=2e-4,
        cuda=True,
        verbose=True,
    )
    synth.fit(df_slice)

    # Save the trained model
    model_path = outdir / f"{service_code}_final.pkl"
    synth.save(str(model_path))

    return synth, model_path


if __name__ == "__main__":
    DATA_PATH = "filtered_data/df_v2_filtered.pkl"
    TOP_K = 5

    df = pd.read_pickle(DATA_PATH)
    codes = df["service_code_description"].value_counts().head(TOP_K).index.tolist()

    print(f"\nTop-{TOP_K} service codes: {codes}\n")

    for code in codes:
        slice_df = df[df["service_code_description"] == code].copy()
        print(f"\nTraining CTGAN for '{code}' ({len(slice_df):,} rows, 200 epochs)")

        _, model_path = train_ctgan(
            slice_df,
            service_code=code,
            epochs=200,
            outdir=Path("checkpoints_3/models"),
        )

        print(f"Model saved to {model_path}")
# Out:
# Top-5 service codes: ['ASSIST MEMBER OF THE PUBLIC', 'CONCERN FOR PERSON', 'DISTURBANCE', 'THEFT', 'DOMESTIC INCIDENT']
#
#
# Training CTGAN for 'ASSIST MEMBER OF THE PUBLIC' (169,406 rows, 200 epochs)
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# Gen. (-0.08) | Discrim. (-0.20): 100%|██████████| 200/200 [15:10<00:00,  4.55s/it]
# Model saved to checkpoints_3/models/ASSIST MEMBER OF THE PUBLIC_final.pkl
#
# Training CTGAN for 'CONCERN FOR PERSON' (121,876 rows, 200 epochs)
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# Gen. (-0.57) | Discrim. (-0.05): 100%|██████████| 200/200 [10:47<00:00,  3.24s/it]
# Model saved to checkpoints_3/models/CONCERN FOR PERSON_final.pkl
#
# Training CTGAN for 'DISTURBANCE' (90,395 rows, 200 epochs)
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# Gen. (-0.63) | Discrim. (-0.07): 100%|██████████| 200/200 [08:00<00:00,  2.40s/it]
# Model saved to checkpoints_3/models/DISTURBANCE_final.pkl
#
# Training CTGAN for 'THEFT' (87,517 rows, 200 epochs)
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# Gen. (-0.21) | Discrim. (-0.04): 100%|██████████| 200/200 [07:47<00:00,  2.34s/it]
# Model saved to checkpoints_3/models/THEFT_final.pkl
#
# Training CTGAN for 'DOMESTIC INCIDENT' (79,291 rows, 200 epochs)
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# Gen. (-0.34) | Discrim. (0.00): 100%|██████████| 200/200 [07:01<00:00,  2.11s/it]
# Model saved to checkpoints_3/models/DOMESTIC INCIDENT_final.pkl

# %% [markdown]
# ## Making more synth data with 200 epoch models

# %%
import pandas as pd

pd.options.display.max_rows = 4000

# Load your filtered dataset from pickle
DATA_PATH = "filtered_data/df_v2_filtered.pkl"

df = pd.read_pickle(DATA_PATH)

# %%
import pandas as pd

# Example: assume df is your full incidents DataFrame
cutoff = 5000

# Identify categories below the cutoff
counts = df['service_code_description'].value_counts()
low_categories = counts[counts < cutoff].index

# Replace low-frequency categories with "OTHER"
df['service_code_description'] = df['service_code_description'].replace(low_categories, 'OTHER')

# Optional: check new distribution
print(df['service_code_description'].value_counts().sort_values(ascending=False))
# Out:
# service_code_description
# ASSIST MEMBER OF THE PUBLIC    169406
# CONCERN FOR PERSON             121876
# DISTURBANCE                     90395
# THEFT                           87517
# DOMESTIC INCIDENT               79291
# ROAD TRAFFIC MATTER             75033
# PUBLIC NUISANCE                 59037
# ROAD TRAFFIC COLLISION          58259
# OTHER                           44717
# ABANDONED/SILENT 999 CALL       41102
# EXTERNAL AGENCY REQUEST         40557
# ASSAULT                         39608
# NOISE                           36849
# DAMAGE                          33240
# NEIGHBOUR DISPUTE               30507
# FALSE CALL                      30413
# COMMUNICATIONS                  29706
# MISSING PERSON/ABSCONDER        27140
# SUSPECT PERSONS                 25141
# POLICE INFORMATION              20941
# FRAUD INCIDENT                  20360
# ROAD TRAFFIC OFFENCE            18563
# CHILD PROTECTION                17091
# DRUGS/SUBSTANCE MISUSE          16948
# VEHICLE CRIME                   15139
# DOMESTIC BAIL CHECK             15002
# TASK INCIDENT                   13296
# SUDDEN DEATH                    12499
# POLICE GENERATED ACTIVITY       12498
# HOUSEBREAKING                   12065
# ANIMALS                         10139
# BAIL/CURFEW/ADDRESS CHECKS      10069
# SEXUAL OFFENCE                   8471
# FIRES                            6129
# HATE CRIME                       5983
# ABANDONED VEHICLES               5360
# Name: count, dtype: int64

# %%
from pathlib import Path
from typing import Tuple
import pandas as pd
import ray
import torch
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata


def train_ctgan(df_slice: pd.DataFrame, service_code: str, epochs: int, outdir: Path) -> Path:
    """Train a CTGAN on one slice (GPU assumed available) and save the model."""
    outdir.mkdir(parents=True, exist_ok=True)

    meta = SingleTableMetadata()
    meta.detect_from_dataframe(df_slice)
    meta.validate()

    synth = CTGANSynthesizer(
        meta,
        epochs=epochs,
        batch_size=1024,
        pac=8,
        embedding_dim=128,
        generator_dim=(256, 256),
        discriminator_dim=(256, 256),
        generator_lr=2e-4,
        discriminator_lr=2e-4,
        cuda=True,
        verbose=False,
    )
    synth.fit(df_slice)

    model_path = outdir / f"{service_code}_final.pkl"
    synth.save(str(model_path))
    return model_path


@ray.remote(num_gpus=1)  # One GPU per slice
def train_actor(df_slice: pd.DataFrame, service_code: str, epochs: int, outdir: str) -> str:
    torch.cuda.set_device(0)  # Ray handles GPU assignment
    return str(train_ctgan(df_slice, service_code, epochs, Path(outdir)))


if __name__ == "__main__":
    ray.init()
    CATEGORY_COL = "service_code_description"
    EPOCHS = 200
    OUTDIR = "checkpoints_4/models"

    categories = df[CATEGORY_COL].value_counts().index.tolist()

    print(f"Launching CTGAN training for {len(categories)} slices on multiple GPUs...")

    futures = []
    for code in categories:
        slice_df = df[df[CATEGORY_COL] == code].copy()
        futures.append(train_actor.remote(slice_df, code, EPOCHS, OUTDIR))

    results = ray.get(futures)

    for r in results:
        print(f"✅ Saved: {r}")

    ray.shutdown()
# Out:
# 2025-08-09 08:19:21,013	INFO worker.py:1927 -- Started a local Ray instance.
# Launching CTGAN training for 36 slices on multiple GPUs...
# (train_actor pid=294117) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=294117)
# (train_actor pid=294117) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=294117)
# (train_actor pid=294117) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=294117)
# (train_actor pid=294117) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=294117)
# (train_actor pid=294117) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=294117)
# (train_actor pid=294117) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=294117)
# (train_actor pid=294117) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning:
# (train_actor pid=294117)
# (train_actor pid=294117) resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
# (train_actor pid=294117)
# (train_actor pid=294117) Traceback (most recent call last):
# (train_actor pid=294117)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294117)     del registry[rtype][name]
# (train_actor pid=294117)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294117) KeyError: '/dev/shm/joblib_memmapping_folder_294117_73302cc02cf94569b0ebc047eeb10783_5890e72a651149a3b3547e31148ab579'
# (train_actor pid=294117) Traceback (most recent call last):
# (train_actor pid=294117)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294117)     del registry[rtype][name]
# (train_actor pid=294117)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294117) KeyError: '/loky-294117-fb77_r29'
# (train_actor pid=294117) Traceback (most recent call last):
# (train_actor pid=294117)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294117)     del registry[rtype][name]
# (train_actor pid=294117)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294117) KeyError: '/loky-294117-hm341mc4'
# (train_actor pid=294117) Traceback (most recent call last):
# (train_actor pid=294117)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294117)     del registry[rtype][name]
# (train_actor pid=294117)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294117) KeyError: '/loky-294117-vsfvqab_'
# (train_actor pid=294117) Traceback (most recent call last):
# (train_actor pid=294117)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294117)     del registry[rtype][name]
# (train_actor pid=294117)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294117) KeyError: '/loky-294117-1kv0r23n'
# (train_actor pid=294117) Traceback (most recent call last):
# (train_actor pid=294117)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294117)     del registry[rtype][name]
# (train_actor pid=294117)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294117) KeyError: '/loky-294117-g9qalru5'
# (train_actor pid=294117) Traceback (most recent call last):
# (train_actor pid=294117)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294117)     del registry[rtype][name]
# (train_actor pid=294117)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294117) KeyError: '/loky-294117-aprz_ww7'
# (train_actor pid=294113) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=294113)
# (train_actor pid=294113) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=294113)
# (train_actor pid=294113) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=294113)
# (train_actor pid=294113) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=294113)
# (train_actor pid=294113) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=294113)
# (train_actor pid=294113) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=294113)
# (train_actor pid=294113) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning:
# (train_actor pid=294113)
# (train_actor pid=294113) resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
# (train_actor pid=294113)
# (train_actor pid=294113) Traceback (most recent call last):
# (train_actor pid=294113)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294113)     del registry[rtype][name]
# (train_actor pid=294113)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294113) KeyError: '/dev/shm/joblib_memmapping_folder_294113_935f33d4f69044179c9fd6231564f475_7de833ecc9444bc5b76536f9344953dc'
# (train_actor pid=294113) Traceback (most recent call last):
# (train_actor pid=294113)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294113)     del registry[rtype][name]
# (train_actor pid=294113)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294113) KeyError: '/loky-294113-2q2imou7'
# (train_actor pid=294113) Traceback (most recent call last):
# (train_actor pid=294113)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294113)     del registry[rtype][name]
# (train_actor pid=294113)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294113) KeyError: '/loky-294113-9nf_4fv3'
# (train_actor pid=294113) Traceback (most recent call last):
# (train_actor pid=294113)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294113)     del registry[rtype][name]
# (train_actor pid=294113)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294113) KeyError: '/loky-294113-aum6b0j6'
# (train_actor pid=294113) Traceback (most recent call last):
# (train_actor pid=294113)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294113)     del registry[rtype][name]
# (train_actor pid=294113)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294113) KeyError: '/loky-294113-lgjaehgl'
# (train_actor pid=294113) Traceback (most recent call last):
# (train_actor pid=294113)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294113)     del registry[rtype][name]
# (train_actor pid=294113)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294113) KeyError: '/loky-294113-zrxr03bb'
# (train_actor pid=294113) Traceback (most recent call last):
# (train_actor pid=294113)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294113)     del registry[rtype][name]
# (train_actor pid=294113)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294113) KeyError: '/loky-294113-gaxrvprw'
# (train_actor pid=294114) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=294114)
# (train_actor pid=294114) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=294114)
# (train_actor pid=294114) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=294114)
# (train_actor pid=294114) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=294114)
# (train_actor pid=294114) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=294114)
# (train_actor pid=294114) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=294114)
# (train_actor pid=294114) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning:
# (train_actor pid=294114)
# (train_actor pid=294114) resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
# (train_actor pid=294114)
# (train_actor pid=294114) Traceback (most recent call last):
# (train_actor pid=294114)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294114)     del registry[rtype][name]
# (train_actor pid=294114)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294114) KeyError: '/dev/shm/joblib_memmapping_folder_294114_9408190fa8b04f318e46befd6d2406b3_29845c7328f24087aeeac6903449fa6d'
# (train_actor pid=294114) Traceback (most recent call last):
# (train_actor pid=294114)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294114)     del registry[rtype][name]
# (train_actor pid=294114)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294114) KeyError: '/loky-294114-c71ue0bm'
# (train_actor pid=294114) Traceback (most recent call last):
# (train_actor pid=294114)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294114)     del registry[rtype][name]
# (train_actor pid=294114)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294114) KeyError: '/loky-294114-rir9i_80'
# (train_actor pid=294114) Traceback (most recent call last):
# (train_actor pid=294114)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294114)     del registry[rtype][name]
# (train_actor pid=294114)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294114) KeyError: '/loky-294114-iiw6pua4'
# (train_actor pid=294114) Traceback (most recent call last):
# (train_actor pid=294114)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294114)     del registry[rtype][name]
# (train_actor pid=294114)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294114) KeyError: '/loky-294114-txjp1o2n'
# (train_actor pid=294114) Traceback (most recent call last):
# (train_actor pid=294114)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294114)     del registry[rtype][name]
# (train_actor pid=294114)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294114) KeyError: '/loky-294114-uyzmi3wk'
# (train_actor pid=294114) Traceback (most recent call last):
# (train_actor pid=294114)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294114)     del registry[rtype][name]
# (train_actor pid=294114)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294114) KeyError: '/loky-294114-wyzl5ta_'
# (train_actor pid=294118) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=294118)
# (train_actor pid=294118) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=294118)
# (train_actor pid=294118) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=294118)
# (train_actor pid=294118) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=294118)
# (train_actor pid=294118) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=294118)
# (train_actor pid=294118) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=294118)
# (train_actor pid=294118) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning:
# (train_actor pid=294118)
# (train_actor pid=294118)
# (train_actor pid=294118) resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
# (train_actor pid=294118) Traceback (most recent call last):
# (train_actor pid=294118)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294118)     del registry[rtype][name]
# (train_actor pid=294118)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294118) KeyError: '/dev/shm/joblib_memmapping_folder_294118_9328ca32165d4957bbd19a91cd719c50_48ad85a410b146d2add29dd1e1ab21b5'
# (train_actor pid=294118) Traceback (most recent call last):
# (train_actor pid=294118)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294118)     del registry[rtype][name]
# (train_actor pid=294118)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294118) KeyError: '/loky-294118-czma3a3n'
# (train_actor pid=294118) Traceback (most recent call last):
# (train_actor pid=294118)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294118)     del registry[rtype][name]
# (train_actor pid=294118)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294118) KeyError: '/loky-294118-ehy3sb4_'
# (train_actor pid=294118) Traceback (most recent call last):
# (train_actor pid=294118)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294118)     del registry[rtype][name]
# (train_actor pid=294118)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294118) KeyError: '/loky-294118-o892ow3r'
# (train_actor pid=294118) Traceback (most recent call last):
# (train_actor pid=294118)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294118)     del registry[rtype][name]
# (train_actor pid=294118)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294118) KeyError: '/loky-294118-85sh7u2q'
# (train_actor pid=294118) Traceback (most recent call last):
# (train_actor pid=294118)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294118)     del registry[rtype][name]
# (train_actor pid=294118)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294118) KeyError: '/loky-294118-q_vm35t2'
# (train_actor pid=294118) Traceback (most recent call last):
# (train_actor pid=294118)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294118)     del registry[rtype][name]
# (train_actor pid=294118)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294118) KeyError: '/loky-294118-y8ha8mdp'
# (train_actor pid=294116) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=294116)
# (train_actor pid=294116) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=294116)
# (train_actor pid=294116) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=294116)
# (train_actor pid=294116) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=294116)
# (train_actor pid=294116) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=294116)
# (train_actor pid=294116) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=294116)
# (train_actor pid=294116) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning:
# (train_actor pid=294116)
# (train_actor pid=294116) resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
# (train_actor pid=294116)
# (train_actor pid=294116) Traceback (most recent call last):
# (train_actor pid=294116)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294116)     del registry[rtype][name]
# (train_actor pid=294116)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294116) KeyError: '/dev/shm/joblib_memmapping_folder_294116_92db784ae0bf4a97a9cf18b53e0a5f50_e8865d3a52174a3b9a5c4d5682ba20a6'
# (train_actor pid=294116) Traceback (most recent call last):
# (train_actor pid=294116)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294116)     del registry[rtype][name]
# (train_actor pid=294116)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294116) KeyError: '/loky-294116-w4bnrn8w'
# (train_actor pid=294116) Traceback (most recent call last):
# (train_actor pid=294116)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294116)     del registry[rtype][name]
# (train_actor pid=294116)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294116) KeyError: '/loky-294116-ybhrkz1h'
# (train_actor pid=294116) Traceback (most recent call last):
# (train_actor pid=294116)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294116)     del registry[rtype][name]
# (train_actor pid=294116)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294116) KeyError: '/loky-294116-aj2udo1k'
# (train_actor pid=294116) Traceback (most recent call last):
# (train_actor pid=294116)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294116)     del registry[rtype][name]
# (train_actor pid=294116)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294116) KeyError: '/loky-294116-myqj95g7'
# (train_actor pid=294116) Traceback (most recent call last):
# (train_actor pid=294116)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294116)     del registry[rtype][name]
# (train_actor pid=294116)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294116) KeyError: '/loky-294116-h_ux41gp'
# (train_actor pid=294116) Traceback (most recent call last):
# (train_actor pid=294116)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294116)     del registry[rtype][name]
# (train_actor pid=294116)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294116) KeyError: '/loky-294116-f301z814'
# (train_actor pid=294115) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=294115)
# (train_actor pid=294115) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=294115)
# (train_actor pid=294115) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=294115)
# (train_actor pid=294115) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=294115)
# (train_actor pid=294115) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=294115)
# (train_actor pid=294115) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=294115)
# (train_actor pid=294115) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning:
# (train_actor pid=294115)
# (train_actor pid=294115)
# (train_actor pid=294115) resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
# (train_actor pid=294115) Traceback (most recent call last):
# (train_actor pid=294115)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294115)     del registry[rtype][name]
# (train_actor pid=294115)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294115) KeyError: '/dev/shm/joblib_memmapping_folder_294115_99a4d9c69c8d4a898b2f85d2c690af5d_49d2fdd8b5e84a0f8055eb3ca70b80eb'
# (train_actor pid=294115) Traceback (most recent call last):
# (train_actor pid=294115)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294115)     del registry[rtype][name]
# (train_actor pid=294115)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294115) KeyError: '/loky-294115-edgcl9xx'
# (train_actor pid=294115) Traceback (most recent call last):
# (train_actor pid=294115)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294115)     del registry[rtype][name]
# (train_actor pid=294115)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294115) KeyError: '/loky-294115-unuu6306'
# (train_actor pid=294115) Traceback (most recent call last):
# (train_actor pid=294115)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294115)     del registry[rtype][name]
# (train_actor pid=294115)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294115) KeyError: '/loky-294115-g0s0g36p'
# (train_actor pid=294115) Traceback (most recent call last):
# (train_actor pid=294115)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294115)     del registry[rtype][name]
# (train_actor pid=294115)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294115) KeyError: '/loky-294115-3m65nu4y'
# (train_actor pid=294115) Traceback (most recent call last):
# (train_actor pid=294115)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294115)     del registry[rtype][name]
# (train_actor pid=294115)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294115) KeyError: '/loky-294115-6yh0il2u'
# (train_actor pid=294115) Traceback (most recent call last):
# (train_actor pid=294115)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=294115)     del registry[rtype][name]
# (train_actor pid=294115)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=294115) KeyError: '/loky-294115-96rdqyc6'
# (train_actor pid=298344) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=298344)
# (train_actor pid=298344) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=298344)
# (train_actor pid=298344) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=298344)
# (train_actor pid=298344) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=298344)
# (train_actor pid=298344) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=298344)
# (train_actor pid=298344) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=298344)
# (train_actor pid=298344) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning:
# (train_actor pid=298344)
# (train_actor pid=298344) resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
# (train_actor pid=298344)
# (train_actor pid=298344) Traceback (most recent call last):
# (train_actor pid=298344)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=298344)     del registry[rtype][name]
# (train_actor pid=298344)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=298344) KeyError: '/dev/shm/joblib_memmapping_folder_298344_84f3de932e5e4ba59a1edf08acffc3da_5b4709822ae54971871ea4d1dce77c82'
# (train_actor pid=298344) Traceback (most recent call last):
# (train_actor pid=298344)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=298344)     del registry[rtype][name]
# (train_actor pid=298344)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=298344) KeyError: '/loky-298344-4el5uic9'
# (train_actor pid=298344) Traceback (most recent call last):
# (train_actor pid=298344)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=298344)     del registry[rtype][name]
# (train_actor pid=298344)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=298344) KeyError: '/loky-298344-n_a64vkp'
# (train_actor pid=298344) Traceback (most recent call last):
# (train_actor pid=298344)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=298344)     del registry[rtype][name]
# (train_actor pid=298344)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=298344) KeyError: '/loky-298344-dk4g9ryu'
# (train_actor pid=298344) Traceback (most recent call last):
# (train_actor pid=298344)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=298344)     del registry[rtype][name]
# (train_actor pid=298344)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=298344) KeyError: '/loky-298344-kveukqg8'
# (train_actor pid=298344) Traceback (most recent call last):
# (train_actor pid=298344)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=298344)     del registry[rtype][name]
# (train_actor pid=298344)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=298344) KeyError: '/loky-298344-vcjm2byo'
# (train_actor pid=298344) Traceback (most recent call last):
# (train_actor pid=298344)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=298344)     del registry[rtype][name]
# (train_actor pid=298344)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=298344) KeyError: '/loky-298344-j9zpsefe'
# (train_actor pid=298708) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=298708)
# (train_actor pid=298708) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=298708)
# (train_actor pid=298708) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=298708)
# (train_actor pid=298708) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=298708)
# (train_actor pid=298708) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=298708)
# (train_actor pid=298708) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=298708)
# (train_actor pid=298708) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning:
# (train_actor pid=298708)
# (train_actor pid=298708) resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
# (train_actor pid=298708)
# (train_actor pid=298708) Traceback (most recent call last):
# (train_actor pid=298708)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=298708)     del registry[rtype][name]
# (train_actor pid=298708)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=298708) KeyError: '/dev/shm/joblib_memmapping_folder_298708_439dfb83cbcc48f69540e8b045c5ebfa_e38f7f9a9744436bb39dc69f57cddaf7'
# (train_actor pid=298708) Traceback (most recent call last):
# (train_actor pid=298708)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=298708)     del registry[rtype][name]
# (train_actor pid=298708)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=298708) KeyError: '/loky-298708-tovrqlq5'
# (train_actor pid=298708) Traceback (most recent call last):
# (train_actor pid=298708)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=298708)     del registry[rtype][name]
# (train_actor pid=298708)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=298708) KeyError: '/loky-298708-5i5z4cl3'
# (train_actor pid=298708) Traceback (most recent call last):
# (train_actor pid=298708)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=298708)     del registry[rtype][name]
# (train_actor pid=298708)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=298708) KeyError: '/loky-298708-_aix2aut'
# (train_actor pid=298708) Traceback (most recent call last):
# (train_actor pid=298708)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=298708)     del registry[rtype][name]
# (train_actor pid=298708)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=298708) KeyError: '/loky-298708-r5l5s7hd'
# (train_actor pid=298708) Traceback (most recent call last):
# (train_actor pid=298708)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=298708)     del registry[rtype][name]
# (train_actor pid=298708)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=298708) KeyError: '/loky-298708-qthd_sv0'
# (train_actor pid=298708) Traceback (most recent call last):
# (train_actor pid=298708)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=298708)     del registry[rtype][name]
# (train_actor pid=298708)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=298708) KeyError: '/loky-298708-7nkaz59o'
# (train_actor pid=299036) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=299036)
# (train_actor pid=299036) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=299036)
# (train_actor pid=299036) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=299036)
# (train_actor pid=299036) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=299036)
# (train_actor pid=299036) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=299036)
# (train_actor pid=299036) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=299036)
# (train_actor pid=299036) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning:
# (train_actor pid=299036)
# (train_actor pid=299036) resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
# (train_actor pid=299036)
# (train_actor pid=299036) Traceback (most recent call last):
# (train_actor pid=299036)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299036)     del registry[rtype][name]
# (train_actor pid=299036)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299036) KeyError: '/loky-299036-du8uudz1'
# (train_actor pid=299036) Traceback (most recent call last):
# (train_actor pid=299036)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299036)     del registry[rtype][name]
# (train_actor pid=299036)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299036) KeyError: '/loky-299036-q9pgshbj'
# (train_actor pid=299036) Traceback (most recent call last):
# (train_actor pid=299036)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299036)     del registry[rtype][name]
# (train_actor pid=299036)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299036) KeyError: '/loky-299036-ux34fk_t'
# (train_actor pid=299036) Traceback (most recent call last):
# (train_actor pid=299036)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299036)     del registry[rtype][name]
# (train_actor pid=299036)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299036) KeyError: '/loky-299036-3et7srg1'
# (train_actor pid=299036) Traceback (most recent call last):
# (train_actor pid=299036)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299036)     del registry[rtype][name]
# (train_actor pid=299036)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299036) KeyError: '/loky-299036-ujnh5yg5'
# (train_actor pid=299036) Traceback (most recent call last):
# (train_actor pid=299036)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299036)     del registry[rtype][name]
# (train_actor pid=299036)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299036) KeyError: '/dev/shm/joblib_memmapping_folder_299036_fa4bcb70ba604b6b95f0ccf57735d2a3_7388333572fc4c4cb62e2961b5e587d5'
# (train_actor pid=299036) Traceback (most recent call last):
# (train_actor pid=299036)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299036)     del registry[rtype][name]
# (train_actor pid=299036)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299036) KeyError: '/loky-299036-qqkhcfqo'
# (train_actor pid=299036) Traceback (most recent call last):
# (train_actor pid=299036)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299036)     del registry[rtype][name]
# (train_actor pid=299036)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299036) KeyError: '/loky-299036-mq570jrb'
# (train_actor pid=299036) Traceback (most recent call last):
# (train_actor pid=299036)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299036)     del registry[rtype][name]
# (train_actor pid=299036)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299036) KeyError: '/loky-299036-rdvw1k_6'
# (train_actor pid=299036) Traceback (most recent call last):
# (train_actor pid=299036)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299036)     del registry[rtype][name]
# (train_actor pid=299036)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299036) KeyError: '/loky-299036-f7bx1lgm'
# (train_actor pid=299036) Traceback (most recent call last):
# (train_actor pid=299036)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299036)     del registry[rtype][name]
# (train_actor pid=299036)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299036) KeyError: '/loky-299036-p8atql0t'
# (train_actor pid=299036) Traceback (most recent call last):
# (train_actor pid=299036)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299036)     del registry[rtype][name]
# (train_actor pid=299036)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299036) KeyError: '/loky-299036-9rrlegbu'
# (train_actor pid=299036) Traceback (most recent call last):
# (train_actor pid=299036)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299036)     del registry[rtype][name]
# (train_actor pid=299036)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299036) KeyError: '/loky-299036-po4bk0vi'
# (train_actor pid=299455) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=299455)
# (train_actor pid=299455) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=299455)
# (train_actor pid=299455) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=299455)
# (train_actor pid=299455) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=299455)
# (train_actor pid=299455) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=299455)
# (train_actor pid=299455) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=299455)
# (train_actor pid=299455) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning:
# (train_actor pid=299455)
# (train_actor pid=299455) resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
# (train_actor pid=299455)
# (train_actor pid=299455) Traceback (most recent call last):
# (train_actor pid=299455)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299455)     del registry[rtype][name]
# (train_actor pid=299455)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299455) KeyError: '/loky-299455-s2b43x8g'
# (train_actor pid=299455) Traceback (most recent call last):
# (train_actor pid=299455)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299455)     del registry[rtype][name]
# (train_actor pid=299455)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299455) KeyError: '/loky-299455-72wy_xuz'
# (train_actor pid=299455) Traceback (most recent call last):
# (train_actor pid=299455)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299455)     del registry[rtype][name]
# (train_actor pid=299455)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299455) KeyError: '/loky-299455-rszp1c7n'
# (train_actor pid=299455) Traceback (most recent call last):
# (train_actor pid=299455)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299455)     del registry[rtype][name]
# (train_actor pid=299455)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299455) KeyError: '/loky-299455-mbiuwaw0'
# (train_actor pid=299455) Traceback (most recent call last):
# (train_actor pid=299455)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299455)     del registry[rtype][name]
# (train_actor pid=299455)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299455) KeyError: '/loky-299455-jfbibdp7'
# (train_actor pid=299455) Traceback (most recent call last):
# (train_actor pid=299455)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299455)     del registry[rtype][name]
# (train_actor pid=299455)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299455) KeyError: '/dev/shm/joblib_memmapping_folder_299455_462826a7a246455d92a4eafad4e77f6a_1515e14d463e4ee58171e6dc19484737'
# (train_actor pid=299455) Traceback (most recent call last):
# (train_actor pid=299455)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299455)     del registry[rtype][name]
# (train_actor pid=299455)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299455) KeyError: '/loky-299455-_8pkqrdn'
# (train_actor pid=299455) Traceback (most recent call last):
# (train_actor pid=299455)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299455)     del registry[rtype][name]
# (train_actor pid=299455)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299455) KeyError: '/loky-299455-gsgg7qit'
# (train_actor pid=299455) Traceback (most recent call last):
# (train_actor pid=299455)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299455)     del registry[rtype][name]
# (train_actor pid=299455)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299455) KeyError: '/loky-299455-zqoixkf6'
# (train_actor pid=299455) Traceback (most recent call last):
# (train_actor pid=299455)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299455)     del registry[rtype][name]
# (train_actor pid=299455)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299455) KeyError: '/loky-299455-hyirpl9_'
# (train_actor pid=299455) Traceback (most recent call last):
# (train_actor pid=299455)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299455)     del registry[rtype][name]
# (train_actor pid=299455)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299455) KeyError: '/loky-299455-c_x87574'
# (train_actor pid=299455) Traceback (most recent call last):
# (train_actor pid=299455)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299455)     del registry[rtype][name]
# (train_actor pid=299455)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299455) KeyError: '/loky-299455-6cculdl_'
# (train_actor pid=299455) Traceback (most recent call last):
# (train_actor pid=299455)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=299455)     del registry[rtype][name]
# (train_actor pid=299455)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=299455) KeyError: '/loky-299455-8dnrw5ut'
# ---------------------------------------------------------------------------
# RayTaskError(FileNotFoundError)           Traceback (most recent call last)
# Cell In[3], line 59
#      56     slice_df = df[df[CATEGORY_COL] == code].copy()
#      57     futures.append(train_actor.remote(slice_df, code, EPOCHS, OUTDIR))
# ---> 59 results = ray.get(futures)
#      61 for r in results:
#      62     print(f"✅ Saved: {r}")
#
# File /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/ray/_private/auto_init_hook.py:22, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      19 @wraps(fn)
#      20 def auto_init_wrapper(*args, **kwargs):
#      21     auto_init_ray()
# ---> 22     return fn(*args, **kwargs)
#
# File /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/ray/_private/client_mode_hook.py:104, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     102     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     103         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 104 return func(*args, **kwargs)
#
# File /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/ray/_private/worker.py:2858, in get(object_refs, timeout)
#    2852     raise ValueError(
#    2853         f"Invalid type of object refs, {type(object_refs)}, is given. "
#    2854         "'object_refs' must either be an ObjectRef or a list of ObjectRefs. "
#    2855     )
#    2857 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 2858 values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    2859 for i, value in enumerate(values):
#    2860     if isinstance(value, RayError):
#
# File /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/ray/_private/worker.py:958, in Worker.get_objects(self, object_refs, timeout, return_exceptions, skip_deserialization)
#     956     global_worker.core_worker.dump_object_store_memory_usage()
#     957 if isinstance(value, RayTaskError):
# --> 958     raise value.as_instanceof_cause()
#     959 else:
#     960     raise value
#
# RayTaskError(FileNotFoundError): ray::train_actor() (pid=299455, ip=10.131.34.65)
#   File "/tmp/dcs-tmp.u2164966/ipykernel_293942/693837314.py", line 41, in train_actor
#   File "/tmp/dcs-tmp.u2164966/ipykernel_293942/693837314.py", line 34, in train_ctgan
#   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py", line 695, in save
#     with open(filepath, 'wb') as output:
#          ^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'checkpoints_4/models/ABANDONED/SILENT 999 CALL_final.pkl'
# (train_actor pid=299709) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=299709)
# (train_actor pid=299709) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=299709)
# (train_actor pid=299709) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=299709)
# (train_actor pid=299709) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=299709)
# (train_actor pid=299709) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=299709)
# (train_actor pid=299709) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=299709)

# %%
from pathlib import Path
import pandas as pd
import ray
import torch
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata


def sanitize_filename(name: str) -> str:
    """Replace illegal filename characters with underscores."""
    return name.replace("/", "_").replace("\\", "_")


def train_ctgan(df_slice: pd.DataFrame, service_code: str, epochs: int, outdir: Path) -> Path:
    """Train a CTGAN on one slice (GPU assumed available) and save the model."""
    outdir.mkdir(parents=True, exist_ok=True)

    meta = SingleTableMetadata()
    meta.detect_from_dataframe(df_slice)
    meta.validate()

    synth = CTGANSynthesizer(
        meta,
        epochs=epochs,
        batch_size=1024,
        pac=8,
        embedding_dim=128,
        generator_dim=(256, 256),
        discriminator_dim=(256, 256),
        generator_lr=2e-4,
        discriminator_lr=2e-4,
        cuda=True,
        verbose=False,
    )
    synth.fit(df_slice)

    safe_name = sanitize_filename(service_code)
    model_path = outdir / f"{safe_name}_final.pkl"
    synth.save(str(model_path))
    return model_path


@ray.remote(num_gpus=1)
def train_actor(df_slice: pd.DataFrame, service_code: str, epochs: int, outdir: str) -> str:
    torch.cuda.set_device(0)
    return str(train_ctgan(df_slice, service_code, epochs, Path(outdir)))


if __name__ == "__main__":
    ray.init()
    CATEGORY_COL = "service_code_description"
    EPOCHS = 200
    OUTDIR = "checkpoints_4/models"

    target_codes = [
        "ABANDONED/SILENT 999 CALL",
        "MISSING PERSON/ABSCONDER",
        "DRUGS/SUBSTANCE MISUSE",
        "BAIL/CURFEW/ADDRESS CHECKS"
    ]

    print(f"Launching CTGAN training for {len(target_codes)} missing slices on multiple GPUs...")

    futures = []
    for code in target_codes:
        slice_df = df[df[CATEGORY_COL] == code].copy()
        if slice_df.empty:
            print(f"⚠️ Skipping {code}: no data found.")
            continue
        futures.append(train_actor.remote(slice_df, code, EPOCHS, OUTDIR))

    results = ray.get(futures)

    for r in results:
        print(f"✅ Saved: {r}")

    ray.shutdown()
# Out:
# 2025-08-11 15:41:03,131	INFO worker.py:1927 -- Started a local Ray instance.
# Launching CTGAN training for 4 missing slices on multiple GPUs...
# (train_actor pid=56711) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=56711)
# (train_actor pid=56711) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=56711)
# (train_actor pid=56711) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=56711)
# (train_actor pid=56711) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=56711)
# (train_actor pid=56711) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=56711)
# (train_actor pid=56711) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=56711)
# (train_actor pid=56711) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning:
# (train_actor pid=56711)
# (train_actor pid=56711) resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
# (train_actor pid=56711)
# (train_actor pid=56711) Traceback (most recent call last):
# (train_actor pid=56711)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56711)     del registry[rtype][name]
# (train_actor pid=56711)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56711) KeyError: '/dev/shm/joblib_memmapping_folder_56711_a9c14d3d2d3a47abb29bfdc8399d7ce2_96c20d3faa994580b6a1eedefa815614'
# (train_actor pid=56711) Traceback (most recent call last):
# (train_actor pid=56711)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56711)     del registry[rtype][name]
# (train_actor pid=56711)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56711) KeyError: '/loky-56711-wyja2l9a'
# (train_actor pid=56711) Traceback (most recent call last):
# (train_actor pid=56711)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56711)     del registry[rtype][name]
# (train_actor pid=56711)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56711) KeyError: '/loky-56711-0as7_i_u'
# (train_actor pid=56711) Traceback (most recent call last):
# (train_actor pid=56711)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56711)     del registry[rtype][name]
# (train_actor pid=56711)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56711) KeyError: '/loky-56711-cs4i5xd5'
# (train_actor pid=56711) Traceback (most recent call last):
# (train_actor pid=56711)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56711)     del registry[rtype][name]
# (train_actor pid=56711)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56711) KeyError: '/loky-56711-4n_38xr2'
# (train_actor pid=56711) Traceback (most recent call last):
# (train_actor pid=56711)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56711)     del registry[rtype][name]
# (train_actor pid=56711)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56711) KeyError: '/loky-56711-je63ck49'
# (train_actor pid=56711) Traceback (most recent call last):
# (train_actor pid=56711)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56711)     del registry[rtype][name]
# (train_actor pid=56711)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56711) KeyError: '/loky-56711-1zw5895c'
# (train_actor pid=56711) Traceback (most recent call last):
# (train_actor pid=56711)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56711)     del registry[rtype][name]
# (train_actor pid=56711)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56711) KeyError: '/loky-56711-w5uuq89a'
# (train_actor pid=56711) Traceback (most recent call last):
# (train_actor pid=56711)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56711)     del registry[rtype][name]
# (train_actor pid=56711)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56711) KeyError: '/loky-56711-3d08vyy3'
# (train_actor pid=56711) Traceback (most recent call last):
# (train_actor pid=56711)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56711)     del registry[rtype][name]
# (train_actor pid=56711)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56711) KeyError: '/loky-56711-8a9wjvbf'
# (train_actor pid=56711) Traceback (most recent call last):
# (train_actor pid=56711)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56711)     del registry[rtype][name]
# (train_actor pid=56711)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56711) KeyError: '/loky-56711-y1kgjvj2'
# (train_actor pid=56711) Traceback (most recent call last):
# (train_actor pid=56711)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56711)     del registry[rtype][name]
# (train_actor pid=56711)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56711) KeyError: '/loky-56711-q2ov6hqe'
# (train_actor pid=56711) Traceback (most recent call last):
# (train_actor pid=56711)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56711)     del registry[rtype][name]
# (train_actor pid=56711)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56711) KeyError: '/loky-56711-y7rriso7'
# (train_actor pid=56714) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=56714)
# (train_actor pid=56714) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=56714)
# (train_actor pid=56714) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=56714)
# (train_actor pid=56714) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=56714)
# (train_actor pid=56714) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=56714)
# (train_actor pid=56714) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=56714)
# (train_actor pid=56714) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning:
# (train_actor pid=56714)
# (train_actor pid=56714)
# (train_actor pid=56714) resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
# (train_actor pid=56714) Traceback (most recent call last):
# (train_actor pid=56714)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56714)     del registry[rtype][name]
# (train_actor pid=56714)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56714) KeyError: '/dev/shm/joblib_memmapping_folder_56714_e13c2ab5713941c894dbe8bd7162554b_66173a76c6c9487bbaedf61b47a395cf'
# (train_actor pid=56714) Traceback (most recent call last):
# (train_actor pid=56714)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56714)     del registry[rtype][name]
# (train_actor pid=56714)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56714) KeyError: '/loky-56714-mmgsbg2m'
# (train_actor pid=56714) Traceback (most recent call last):
# (train_actor pid=56714)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56714)     del registry[rtype][name]
# (train_actor pid=56714)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56714) KeyError: '/loky-56714-9cktxtm0'
# (train_actor pid=56714) Traceback (most recent call last):
# (train_actor pid=56714)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56714)     del registry[rtype][name]
# (train_actor pid=56714)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56714) KeyError: '/loky-56714-k_s45fqd'
# (train_actor pid=56714) Traceback (most recent call last):
# (train_actor pid=56714)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56714)     del registry[rtype][name]
# (train_actor pid=56714)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56714) KeyError: '/loky-56714-1tmywmpr'
# (train_actor pid=56714) Traceback (most recent call last):
# (train_actor pid=56714)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56714)     del registry[rtype][name]
# (train_actor pid=56714)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56714) KeyError: '/loky-56714-jpt9xakq'
# (train_actor pid=56714) Traceback (most recent call last):
# (train_actor pid=56714)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56714)     del registry[rtype][name]
# (train_actor pid=56714)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56714) KeyError: '/loky-56714-wki9c3jr'
# (train_actor pid=56714) Traceback (most recent call last):
# (train_actor pid=56714)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56714)     del registry[rtype][name]
# (train_actor pid=56714)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56714) KeyError: '/loky-56714-v4e25ujy'
# (train_actor pid=56714) Traceback (most recent call last):
# (train_actor pid=56714)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56714)     del registry[rtype][name]
# (train_actor pid=56714)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56714) KeyError: '/loky-56714-d3l1n4da'
# (train_actor pid=56714) Traceback (most recent call last):
# (train_actor pid=56714)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56714)     del registry[rtype][name]
# (train_actor pid=56714)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56714) KeyError: '/loky-56714-7w6h4c65'
# (train_actor pid=56714) Traceback (most recent call last):
# (train_actor pid=56714)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56714)     del registry[rtype][name]
# (train_actor pid=56714)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56714) KeyError: '/loky-56714-o0zlg14y'
# (train_actor pid=56714) Traceback (most recent call last):
# (train_actor pid=56714)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56714)     del registry[rtype][name]
# (train_actor pid=56714)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56714) KeyError: '/loky-56714-71lo34c_'
# (train_actor pid=56714) Traceback (most recent call last):
# (train_actor pid=56714)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56714)     del registry[rtype][name]
# (train_actor pid=56714)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56714) KeyError: '/loky-56714-xx9zy76k'
# (train_actor pid=56715) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=56715)
# (train_actor pid=56715) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=56715)
# (train_actor pid=56715) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=56715)
# (train_actor pid=56715) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=56715)
# (train_actor pid=56715) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=56715)
# (train_actor pid=56715) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=56715)
# (train_actor pid=56715) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning:
# (train_actor pid=56715)
# (train_actor pid=56715) resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
# (train_actor pid=56715)
# (train_actor pid=56715) Traceback (most recent call last):
# (train_actor pid=56715)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56715)     del registry[rtype][name]
# (train_actor pid=56715)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56715) KeyError: '/loky-56715-bi2s9ygn'
# (train_actor pid=56715) Traceback (most recent call last):
# (train_actor pid=56715)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56715)     del registry[rtype][name]
# (train_actor pid=56715)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56715) KeyError: '/loky-56715-rkv14kgk'
# (train_actor pid=56715) Traceback (most recent call last):
# (train_actor pid=56715)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56715)     del registry[rtype][name]
# (train_actor pid=56715)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56715) KeyError: '/loky-56715-1dvs0fey'
# (train_actor pid=56715) Traceback (most recent call last):
# (train_actor pid=56715)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56715)     del registry[rtype][name]
# (train_actor pid=56715)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56715) KeyError: '/loky-56715-eop37936'
# (train_actor pid=56715) Traceback (most recent call last):
# (train_actor pid=56715)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56715)     del registry[rtype][name]
# (train_actor pid=56715)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56715) KeyError: '/dev/shm/joblib_memmapping_folder_56715_ce9fc1fdec7e4d348d472045d6d0acf8_863fa2daf63645f8bd15fa26da46bc9e'
# (train_actor pid=56715) Traceback (most recent call last):
# (train_actor pid=56715)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56715)     del registry[rtype][name]
# (train_actor pid=56715)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56715) KeyError: '/loky-56715-894kmfp2'
# (train_actor pid=56715) Traceback (most recent call last):
# (train_actor pid=56715)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56715)     del registry[rtype][name]
# (train_actor pid=56715)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56715) KeyError: '/loky-56715-kikaccw6'
# (train_actor pid=56715) Traceback (most recent call last):
# (train_actor pid=56715)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56715)     del registry[rtype][name]
# (train_actor pid=56715)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56715) KeyError: '/loky-56715-cin18gfp'
# (train_actor pid=56715) Traceback (most recent call last):
# (train_actor pid=56715)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56715)     del registry[rtype][name]
# (train_actor pid=56715)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56715) KeyError: '/loky-56715-h8_btkz9'
# (train_actor pid=56715) Traceback (most recent call last):
# (train_actor pid=56715)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56715)     del registry[rtype][name]
# (train_actor pid=56715)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56715) KeyError: '/loky-56715-dz6b5y9a'
# (train_actor pid=56715) Traceback (most recent call last):
# (train_actor pid=56715)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56715)     del registry[rtype][name]
# (train_actor pid=56715)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56715) KeyError: '/loky-56715-_gevxcwc'
# (train_actor pid=56715) Traceback (most recent call last):
# (train_actor pid=56715)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56715)     del registry[rtype][name]
# (train_actor pid=56715)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56715) KeyError: '/loky-56715-rfhrtlgs'
# (train_actor pid=56715) Traceback (most recent call last):
# (train_actor pid=56715)   File "/dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py", line 259, in main
# (train_actor pid=56715)     del registry[rtype][name]
# (train_actor pid=56715)         ~~~~~~~~~~~~~~~^^^^^^
# (train_actor pid=56715) KeyError: '/loky-56715-lukpdulo'
# (train_actor pid=56710) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:162: FutureWarning:
# (train_actor pid=56710)
# (train_actor pid=56710) The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
# (train_actor pid=56710)
# (train_actor pid=56710) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/base.py:128: UserWarning:
# (train_actor pid=56710)
# (train_actor pid=56710) We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# (train_actor pid=56710)
# (train_actor pid=56710) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/sdv/single_table/ctgan.py:252: FutureWarning:
# (train_actor pid=56710)
# (train_actor pid=56710) Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# (train_actor pid=56710)
# ✅ Saved: checkpoints_4/models/ABANDONED_SILENT 999 CALL_final.pkl
# ✅ Saved: checkpoints_4/models/MISSING PERSON_ABSCONDER_final.pkl
# ✅ Saved: checkpoints_4/models/DRUGS_SUBSTANCE MISUSE_final.pkl
# ✅ Saved: checkpoints_4/models/BAIL_CURFEW_ADDRESS CHECKS_final.pkl
# (train_actor pid=56710) /dcs/large/u2164966/MSc_Dissertation/myenv/lib64/python3.12/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning:
# (train_actor pid=56710)
# (train_actor pid=56710)
# (train_actor pid=56710) resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
